# %%
import pandas as pd
import numpy as np
import sys
from itertools import combinations, groupby
from collections import Counter
from IPython.display import display
import json
from fim import apriori, fpgrowth, eclat
import matplotlib.pyplot as plt
import time

# %%
# Source
# http://sideeffects.embl.de/download/
# SIDER

# %% [markdown]
# # Data preparation

# %%
id_name = pd.read_csv('./side_effects/drug_names.tsv', sep='\t', header=None, names=['id', 'name'])
id_name
# Out:
#                 id                      name
# 0     CID100000085                 carnitine
# 1     CID100000119        gamma-aminobutyric
# 2     CID100000137          5-aminolevulinic
# 3     CID100000143                leucovorin
# 4     CID100000146  5-methyltetrahydrofolate
# ...            ...                       ...
# 1425  CID156603655                pegaptanib
# 1426  CID156842239                       n-3
# 1427  CID170683024                         x
# 1428  CID170695640             colestyramine
# 1429  CID171306834                      K779
#
# [1430 rows x 2 columns]

# %%
dataset = pd.read_csv('./side_effects/meddra_all_se.tsv', sep='\t', header=None, 
            names=['id_1', 'id_2', 'UMLS_id', 'MedDRA_type', 'UMLS_id_for_MedDRA', 'side_effect'])

dataset=dataset[['id_1', 'id_2', 'side_effect']]
#dataset = dataset['id_1'].map(id_name.set_index('id')['name'])
#dataset = dataset['id_2'].map(id_name.set_index('id')['name'])
dataset
# Out:
#                 id_1          id_2            side_effect
# 0       CID100000085  CID000010917       Abdominal cramps
# 1       CID100000085  CID000010917         Abdominal pain
# 2       CID100000085  CID000010917         Abdominal pain
# 3       CID100000085  CID000010917  Gastrointestinal pain
# 4       CID100000085  CID000010917         Abdominal pain
# ...              ...           ...                    ...
# 309844  CID171306834  CID071306834    Respiratory failure
# 309845  CID171306834  CID071306834        Abnormal vision
# 309846  CID171306834  CID071306834      Visual impairment
# 309847  CID171306834  CID071306834                  Warts
# 309848  CID171306834  CID071306834         Skin papilloma
#
# [309849 rows x 3 columns]

# %%
dataset = dataset.groupby(['id_1','id_2'])['side_effect'].apply(list)
dataset
# Out:
# id_1          id_2
# CID100000085  CID000010917    [Abdominal cramps, Abdominal pain, Abdominal p...
# CID100000119  CID000000119    [Anaphylactic shock, Anaphylactic shock, Angio...
# CID100000137  CID000000137    [Anaemia, Anaemia, Aphasia, Aphasia, Mental di...
# CID100000143  CID000000143    [Alopecia, Alopecia, Anorexia, Decreased appet...
#               CID000006006    [Alopecia, Alopecia, Anorexia, Decreased appet...
#                                                     ...
# CID156603655  CID056603655    [Anaphylactic shock, Anaphylactic shock, Angio...
# CID156842239  CID056842239    [Anaphylactic shock, Anaphylactic shock, Const...
# CID170683024  CID070683024    [Angioedema, Angioedema, Chest pain, Chest pai...
# CID170695640  CID070695640    [Abdominal pain, Gastrointestinal pain, Abdomi...
# CID171306834  CID071306834    [Abdominal distension, Abdominal distension, A...
# Name: side_effect, Length: 1556, dtype: object

# %%
transactions=[]

for item in dataset.values:
    transactions.append(list(set(item)))

# %%
transactions[0:4]
# Out:
# [['Body odor',
#   'Dyspnoea',
#   'Hypertonia',
#   'Body temperature increased',
#   'Angiopathy',
#   'Gastrointestinal disorder',
#   'Gastric atony',
#   'Hypotension',
#   'Gastritis',
#   'Myalgia',
#   'Insomnia',
#   'Convulsion',
#   'Decreased appetite',
#   'Renal failure',
#   'Pain',
#   'Accidental injury',
#   'Melaena',
#   'Hypertension',
#   'Infection',
#   'Impaired gastric emptying',
#   'Myasthenia',
#   'Abdominal cramps',
#   'Hyperkalaemia',
#   'Weight increased',
#   'Anorexia',
#   'Pruritus',
#   'Anaemia',
#   'Hypersensitivity',
#   'Parathyroid disorder',
#   'Bronchitis',
#   'Dysgeusia',
#   'Depression',
#   'Arrhythmia',
#   'Oedema peripheral',
#   'Chest pain',
#   'Abdominal pain',
#   'Rash',
#   'Eye disorder',
#   'Sinusitis',
#   'Influenza',
#   'Drug dependence',
#   'Cough',
#   'Dermatitis',
#   'Haemoglobin',
#   'Injury',
#   'Asthenia',
#   'Tachycardia',
#   'Back pain',
#   'Haemorrhage',
#   'Weight decreased',
#   'Cramps of lower extremities',
#   'Amblyopia',
#   'Injection site reaction',
#   'Muscular weakness',
#   'Cardiovascular disorder',
#   'Dyspepsia',
#   'Skin odour abnormal',
#   'Gastrointestinal symptom NOS',
#   'Vomiting',
#   'Muscle spasms',
#   'Headache',
#   'Paraesthesia',
#   'Fluid overload',
#   'Gastrointestinal pain',
#   'Dizziness',
#   'Vertigo',
#   'Hypercalcaemia',
#   'Pharyngitis',
#   'Rhinitis',
#   'Musculoskeletal discomfort',
#   'Diarrhoea',
#   'Anxiety',
#   'Electrocardiogram abnormal',
#   'Constipation',
#   'Palpitations',
#   'Nausea',
#   'Urinary tract infection',
#   'Atrial fibrillation'],
#  ['Anaphylactic shock',
#   'Pain',
#   'Angioedema',
#   'Injection site pain',
#   'Injection site tenderness',
#   'Urticaria'],
#  ['Skin disorder',
#   'Aphasia',
#   'Skin hyperpigmentation',
#   'Body temperature increased',
#   'Infestation',
#   'Angiopathy',
#   'Gastrointestinal disorder',
#   'Skin carcinoma',
#   'Acne',
#   'Hypotension',
#   'Convulsion',
#   'Gamma-glutamyltransferase increased',
#   'Hemiparesis',
#   'Application site reaction',
#   'Seborrhoeic dermatitis',
#   'Hyperkeratosis',
#   'Pain',
#   'Wound secretion',
#   'Discomfort',
#   'Induration',
#   'Infestation NOS',
#   'Skin tightness',
#   'Leukoderma',
#   'Infection',
#   'Blood and lymphatic system disorders',
#   'Excoriation',
#   'Photosensitivity',
#   'Urticaria',
#   'Oedema',
#   'Hypoaesthesia',
#   'Hepatobiliary disease',
#   'Neoplasm',
#   'Rash pustular',
#   'Pruritus',
#   'Blood amylase increased',
#   'Feeling hot',
#   'Anaemia',
#   'Hemianopia',
#   'Cardiac disorder',
#   'Alanine aminotransferase increased',
#   'Unspecified disorder of skin and subcutaneous tissue',
#   'Dry skin',
#   'Herpes simplex',
#   'Tenderness',
#   'Stinging',
#   'Thromboembolism',
#   'Skin cancer',
#   'Nervousness',
#   'Respiratory insufficiency',
#   'Skin hypertrophy',
#   'Application site irritation',
#   'Photosensitivity reaction',
#   'Rash',
#   'Eye disorder',
#   'Accidental ingestion',
#   'Respiratory failure',
#   'Dermatitis',
#   'Haemoglobin',
#   'Eyelid oedema',
#   'Nervous system disorder',
#   'Haemorrhage',
#   'Brain neoplasm',
#   'Amylase increased',
#   'Glioma',
#   'Scab',
#   'Mental disorder',
#   'Warmth',
#   'Ulcer',
#   'Leukocytosis',
#   'Blood bilirubin increased',
#   'Pustule',
#   'Embolism venous',
#   'Rash maculo-papular',
#   'Vomiting',
#   'Erythema',
#   'Thrombocytopenia',
#   'Headache',
#   'Paraesthesia',
#   'Petechiae',
#   'Hyperaesthesia',
#   'Aspartate aminotransferase increased',
#   'Skin exfoliation',
#   'Photodamaged skin',
#   'Tension',
#   'Brain oedema',
#   'Embolism',
#   'Diarrhoea',
#   'Hyperpathia',
#   'Dysaesthesia',
#   'Photodermatosis',
#   'Nausea',
#   'Accidental exposure to product',
#   'Chills',
#   'Welts',
#   'Sunburn'],
#  ['Malaise',
#   'Vomiting',
#   'Rash',
#   'Febrile neutropenia',
#   'Erythema',
#   'Renal failure acute',
#   'Anaphylactic shock',
#   'Serum creatinine increased',
#   'Dermatitis',
#   'Lethargy',
#   'Thrombocytopenia',
#   'Asthenia',
#   'Sensitisation',
#   'Leukopenia',
#   'Anaphylactoid reaction',
#   'Wheezing',
#   'Extravasation',
#   'Anorexia',
#   'Pruritus',
#   'Feeling abnormal',
#   'Alopecia',
#   'Ill-defined disorder',
#   'Stomatitis',
#   'Hypersensitivity',
#   'Convulsion',
#   'Decreased appetite',
#   'Diarrhoea',
#   'Constipation',
#   'Discomfort',
#   'Nausea',
#   'Blood creatinine increased',
#   'Fatigue',
#   'Acute kidney injury',
#   'Infection',
#   'Urticaria']]

# %%
len(transactions)
# Out:
# 1556

# %% [markdown]
# ## Done

# %%
pd.set_option("max_colwidth", 150)

# %%
support=50
confidence=10 
target='rules'
zmin=2 # антицидент+консеквент
zmax=7 # антицидент+консеквент

# %% [markdown]
# # Apriori

# %%
start=time.perf_counter()
fi_apriori = apriori(tracts=transactions, target=target, supp=support, conf=confidence, zmin=zmin)
end=time.perf_counter()
print(end-start)
# Out:
# 0.2797146579996479

# %%
df_apriori = pd.DataFrame.from_records(fi_apriori).sort_values(by=[2],ascending=False).reset_index(drop=True)
df_apriori
# Out:
#                        0                                                  1  \
# 0                   Rash                                      (Dermatitis,)
# 1             Dermatitis                                            (Rash,)
# 2                 Nausea                                        (Vomiting,)
# 3               Vomiting                                          (Nausea,)
# 4               Headache                                          (Nausea,)
# ...                  ...                                                ...
# 72182       Loose stools                 (Abdominal pain, Rash, Dermatitis)
# 72183  Depersonalisation  (Diarrhoea, Vomiting, Rash, Dermatitis, Headache)
# 72184          Toothache            (Asthenia, Dizziness, Vomiting, Nausea)
# 72185        Hypokinesia                   (Asthenia, Vomiting, Dermatitis)
# 72186      Nail disorder      (Diarrhoea, Vomiting, Rash, Headache, Nausea)
#
#           2
# 0      1158
# 1      1158
# 2      1150
# 3      1150
# 4      1103
# ...     ...
# 72182    78
# 72183    78
# 72184    78
# 72185    78
# 72186    78
#
# [72187 rows x 3 columns]

# %% [markdown]
# # FP-Growth

# %%
start=time.perf_counter()
fi_fpgrowth = fpgrowth(tracts=transactions, target=target, supp=support, conf=confidence, zmin=zmin)
end=time.perf_counter()
print(end-start)
# Out:
# 0.10251820299890824

# %%
df_fpgrowth = pd.DataFrame.from_records(fi_fpgrowth).sort_values(by=[2],ascending=False).reset_index(drop=True)
df_fpgrowth
# Out:
#                             0                                        1     2
# 0                  Dermatitis                                  (Rash,)  1158
# 1                        Rash                            (Dermatitis,)  1158
# 2                      Nausea                              (Vomiting,)  1150
# 3                    Vomiting                                (Nausea,)  1150
# 4                      Nausea                              (Headache,)  1103
# ...                       ...                                      ...   ...
# 72182    Cerebration impaired  (Asthenia, Dizziness, Vomiting, Nausea)    78
# 72183  Intestinal obstruction            (Hypersensitivity, Dizziness)    78
# 72184       Vaginal discharge         (Asthenia, Vomiting, Dermatitis)    78
# 72185    Cerebration impaired         (Asthenia, Vomiting, Dermatitis)    78
# 72186                 Aphasia            (Hypersensitivity, Dizziness)    78
#
# [72187 rows x 3 columns]

# %% [markdown]
# # ECLAT

# %%
start=time.perf_counter()
fi_eclat = eclat(tracts=transactions, target=target, supp=support, conf=confidence, zmin=zmin)
end=time.perf_counter()
print(end-start)
# Out:
# 0.12202067699945474

# %%
df_fi_eclat = pd.DataFrame.from_records(fi_eclat).sort_values(by=[2],ascending=False).reset_index(drop=True)
df_fi_eclat
# Out:
#                              0                                       1     2
# 0                   Dermatitis                                 (Rash,)  1158
# 1                         Rash                           (Dermatitis,)  1158
# 2                       Nausea                             (Vomiting,)  1150
# 3                     Vomiting                               (Nausea,)  1150
# 4                     Headache                               (Nausea,)  1103
# ...                        ...                                     ...   ...
# 72182        Vaginal discharge        (Asthenia, Vomiting, Dermatitis)    78
# 72183  Transaminases increased  (Pruritus, Rash, Dermatitis, Headache)    78
# 72184           Thrombocytosis        (Asthenia, Vomiting, Dermatitis)    78
# 72185                    Ileus           (Hypersensitivity, Dizziness)    78
# 72186            Lung disorder        (Asthenia, Vomiting, Dermatitis)    78
#
# [72187 rows x 3 columns]

# %% [markdown]
# ## Association rules

# %%
df_fi_eclat.values.tolist()
# Out:
# [['Dermatitis', ('Rash',), 1158],
#  ['Rash', ('Dermatitis',), 1158],
#  ['Nausea', ('Vomiting',), 1150],
#  ['Vomiting', ('Nausea',), 1150],
#  ['Headache', ('Nausea',), 1103],
#  ['Nausea', ('Headache',), 1103],
#  ['Nausea', ('Rash',), 1069],
#  ['Rash', ('Nausea',), 1069],
#  ['Nausea', ('Dermatitis',), 1069],
#  ['Dermatitis', ('Nausea',), 1069],
#  ['Dermatitis', ('Rash', 'Nausea'), 1054],
#  ['Rash', ('Dermatitis', 'Nausea'), 1054],
#  ['Nausea', ('Rash', 'Dermatitis'), 1054],
#  ['Nausea', ('Dizziness',), 1049],
#  ['Dizziness', ('Nausea',), 1049],
#  ['Dizziness', ('Headache',), 1030],
#  ['Headache', ('Dizziness',), 1030],
#  ['Nausea', ('Diarrhoea',), 1021],
#  ['Diarrhoea', ('Nausea',), 1021],
#  ['Vomiting', ('Headache',), 996],
#  ['Headache', ('Vomiting',), 996],
#  ['Dermatitis', ('Headache',), 994],
#  ['Headache', ('Dermatitis',), 994],
#  ['Rash', ('Headache',), 989],
#  ['Headache', ('Rash',), 989],
#  ['Vomiting', ('Dermatitis',), 986],
#  ['Dermatitis', ('Vomiting',), 986],
#  ['Vomiting', ('Headache', 'Nausea'), 985],
#  ['Nausea', ('Vomiting', 'Headache'), 985],
#  ['Headache', ('Vomiting', 'Nausea'), 985],
#  ['Vomiting', ('Rash',), 982],
#  ['Rash', ('Vomiting',), 982],
#  ['Rash', ('Dermatitis', 'Headache'), 979],
#  ['Dermatitis', ('Rash', 'Headache'), 979],
#  ['Headache', ('Rash', 'Dermatitis'), 979],
#  ['Dizziness', ('Headache', 'Nausea'), 976],
#  ['Nausea', ('Dizziness', 'Headache'), 976],
#  ['Headache', ('Dizziness', 'Nausea'), 976],
#  ['Nausea', ('Vomiting', 'Dermatitis'), 975],
#  ['Dermatitis', ('Vomiting', 'Nausea'), 975],
#  ['Vomiting', ('Dermatitis', 'Nausea'), 975],
#  ['Vomiting', ('Rash', 'Nausea'), 972],
#  ['Rash', ('Vomiting', 'Nausea'), 972],
#  ['Nausea', ('Vomiting', 'Rash'), 972],
#  ['Vomiting', ('Rash', 'Dermatitis'), 971],
#  ['Dermatitis', ('Vomiting', 'Rash'), 971],
#  ['Rash', ('Vomiting', 'Dermatitis'), 971],
#  ['Diarrhoea', ('Vomiting',), 964],
#  ['Vomiting', ('Diarrhoea',), 964],
#  ['Rash', ('Vomiting', 'Dermatitis', 'Nausea'), 961],
#  ['Vomiting', ('Rash', 'Dermatitis', 'Nausea'), 961],
#  ['Nausea', ('Vomiting', 'Rash', 'Dermatitis'), 961],
#  ['Dermatitis', ('Vomiting', 'Rash', 'Nausea'), 961],
#  ['Diarrhoea', ('Vomiting', 'Nausea'), 956],
#  ['Vomiting', ('Diarrhoea', 'Nausea'), 956],
#  ['Nausea', ('Diarrhoea', 'Vomiting'), 956],
#  ['Dizziness', ('Vomiting',), 952],
#  ['Vomiting', ('Dizziness',), 952],
#  ['Dermatitis', ('Dizziness',), 946],
#  ['Dizziness', ('Dermatitis',), 946],
#  ['Nausea', ('Dermatitis', 'Headache'), 946],
#  ['Dermatitis', ('Headache', 'Nausea'), 946],
#  ['Headache', ('Dermatitis', 'Nausea'), 946],
#  ['Dizziness', ('Vomiting', 'Nausea'), 944],
#  ['Vomiting', ('Dizziness', 'Nausea'), 944],
#  ['Nausea', ('Dizziness', 'Vomiting'), 944],
#  ['Dizziness', ('Rash',), 942],
#  ['Rash', ('Dizziness',), 942],
#  ['Nausea', ('Rash', 'Headache'), 942],
#  ['Headache', ('Rash', 'Nausea'), 942],
#  ['Rash', ('Headache', 'Nausea'), 942],
#  ['Nausea', ('Rash', 'Dermatitis', 'Headache'), 934],
#  ['Headache', ('Rash', 'Dermatitis', 'Nausea'), 934],
#  ['Dermatitis', ('Rash', 'Headache', 'Nausea'), 934],
#  ['Rash', ('Dermatitis', 'Headache', 'Nausea'), 934],
#  ['Headache', ('Diarrhoea',), 933],
#  ['Dermatitis', ('Dizziness', 'Rash'), 933],
#  ['Rash', ('Dizziness', 'Dermatitis'), 933],
#  ['Dizziness', ('Rash', 'Dermatitis'), 933],
#  ['Diarrhoea', ('Headache',), 933],
#  ['Asthenia', ('Nausea',), 924],
#  ['Nausea', ('Asthenia',), 924],
#  ['Diarrhoea', ('Dermatitis',), 920],
#  ['Dermatitis', ('Diarrhoea',), 920],
#  ['Nausea', ('Pruritus',), 917],
#  ['Pruritus', ('Nausea',), 917],
#  ['Rash', ('Diarrhoea',), 915],
#  ['Diarrhoea', ('Rash',), 915],
#  ['Pruritus', ('Dermatitis',), 912],
#  ['Dermatitis', ('Pruritus',), 912],
#  ['Dermatitis', ('Dizziness', 'Nausea'), 907],
#  ['Nausea', ('Dizziness', 'Dermatitis'), 907],
#  ['Dizziness', ('Dermatitis', 'Nausea'), 907],
#  ['Rash', ('Diarrhoea', 'Dermatitis'), 906],
#  ['Diarrhoea', ('Rash', 'Dermatitis'), 906],
#  ['Dermatitis', ('Diarrhoea', 'Rash'), 906],
#  ['Nausea', ('Dizziness', 'Rash'), 904],
#  ['Diarrhoea', ('Headache', 'Nausea'), 904],
#  ['Rash', ('Dizziness', 'Nausea'), 904],
#  ['Headache', ('Diarrhoea', 'Nausea'), 904],
#  ['Nausea', ('Diarrhoea', 'Headache'), 904],
#  ['Dizziness', ('Rash', 'Nausea'), 904],
#  ['Diarrhoea', ('Dermatitis', 'Nausea'), 901],
#  ['Dermatitis', ('Diarrhoea', 'Nausea'), 901],
#  ['Nausea', ('Diarrhoea', 'Dermatitis'), 901],
#  ['Pruritus', ('Rash',), 897],
#  ['Rash', ('Pruritus',), 897],
#  ['Nausea', ('Dizziness', 'Rash', 'Dermatitis'), 896],
#  ['Dermatitis', ('Dizziness', 'Rash', 'Nausea'), 896],
#  ['Rash', ('Dizziness', 'Dermatitis', 'Nausea'), 896],
#  ['Dizziness', ('Rash', 'Dermatitis', 'Nausea'), 896],
#  ['Nausea', ('Diarrhoea', 'Rash'), 896],
#  ['Rash', ('Diarrhoea', 'Nausea'), 896],
#  ['Diarrhoea', ('Rash', 'Nausea'), 896],
#  ['Headache', ('Asthenia',), 895],
#  ['Asthenia', ('Headache',), 895],
#  ['Headache', ('Dizziness', 'Vomiting'), 892],
#  ['Dizziness', ('Vomiting', 'Headache'), 892],
#  ['Vomiting', ('Dizziness', 'Headache'), 892],
#  ['Rash', ('Pruritus', 'Dermatitis'), 889],
#  ['Pruritus', ('Rash', 'Dermatitis'), 889],
#  ['Dermatitis', ('Pruritus', 'Rash'), 889],
#  ['Nausea', ('Diarrhoea', 'Rash', 'Dermatitis'), 888],
#  ['Diarrhoea', ('Rash', 'Dermatitis', 'Nausea'), 888],
#  ['Rash', ('Diarrhoea', 'Dermatitis', 'Nausea'), 888],
#  ['Dermatitis', ('Diarrhoea', 'Rash', 'Nausea'), 888],
#  ['Dizziness', ('Dermatitis', 'Headache'), 886],
#  ['Headache', ('Dizziness', 'Dermatitis'), 886],
#  ['Dermatitis', ('Dizziness', 'Headache'), 886],
#  ['Nausea', ('Dizziness', 'Vomiting', 'Headache'), 885],
#  ['Headache', ('Dizziness', 'Vomiting', 'Nausea'), 885],
#  ['Vomiting', ('Dizziness', 'Headache', 'Nausea'), 885],
#  ['Dizziness', ('Vomiting', 'Headache', 'Nausea'), 885],
#  ['Dizziness', ('Diarrhoea',), 884],
#  ['Diarrhoea', ('Dizziness',), 884],
#  ['Dizziness', ('Rash', 'Headache'), 881],
#  ['Rash', ('Dizziness', 'Headache'), 881],
#  ['Headache', ('Dizziness', 'Rash'), 881],
#  ['Nausea', ('Hypersensitivity',), 879],
#  ['Hypersensitivity', ('Nausea',), 879],
#  ['Dizziness', ('Asthenia',), 878],
#  ['Asthenia', ('Dizziness',), 878],
#  ['Dermatitis', ('Vomiting', 'Headache'), 877],
#  ['Headache', ('Vomiting', 'Dermatitis'), 877],
#  ['Vomiting', ('Dermatitis', 'Headache'), 877],
#  ['Rash', ('Dizziness', 'Dermatitis', 'Headache'), 874],
#  ['Dizziness', ('Rash', 'Dermatitis', 'Headache'), 874],
#  ['Headache', ('Dizziness', 'Rash', 'Dermatitis'), 874],
#  ['Dermatitis', ('Dizziness', 'Rash', 'Headache'), 874],
#  ['Vomiting', ('Rash', 'Headache'), 871],
#  ['Headache', ('Vomiting', 'Dermatitis', 'Nausea'), 871],
#  ['Dermatitis', ('Vomiting', 'Headache', 'Nausea'), 871],
#  ['Vomiting', ('Dermatitis', 'Headache', 'Nausea'), 871],
#  ['Nausea', ('Vomiting', 'Dermatitis', 'Headache'), 871],
#  ['Rash', ('Vomiting', 'Headache'), 871],
#  ['Headache', ('Vomiting', 'Rash'), 871],
#  ['Pruritus', ('Headache',), 870],
#  ['Headache', ('Pruritus',), 870],
#  ['Dermatitis', ('Vomiting', 'Rash', 'Headache'), 866],
#  ['Rash', ('Vomiting', 'Dermatitis', 'Headache'), 866],
#  ['Headache', ('Vomiting', 'Rash', 'Dermatitis'), 866],
#  ['Vomiting', ('Rash', 'Dermatitis', 'Headache'), 866],
#  ['Rash', ('Vomiting', 'Headache', 'Nausea'), 865],
#  ['Headache', ('Vomiting', 'Rash', 'Nausea'), 865],
#  ['Nausea', ('Vomiting', 'Rash', 'Headache'), 865],
#  ['Vomiting', ('Rash', 'Headache', 'Nausea'), 865],
#  ['Asthenia', ('Vomiting',), 863],
#  ['Vomiting', ('Asthenia',), 863],
#  ['Vomiting', ('Diarrhoea', 'Dermatitis'), 861],
#  ['Nausea', ('Diarrhoea', 'Dizziness'), 861],
#  ['Diarrhoea', ('Vomiting', 'Dermatitis'), 861],
#  ['Diarrhoea', ('Dizziness', 'Nausea'), 861],
#  ['Dizziness', ('Diarrhoea', 'Nausea'), 861],
#  ['Dermatitis', ('Diarrhoea', 'Vomiting'), 861],
#  ['Headache', ('Vomiting', 'Rash', 'Dermatitis', 'Nausea'), 860],
#  ['Vomiting', ('Rash', 'Dermatitis', 'Headache', 'Nausea'), 860],
#  ['Rash', ('Vomiting', 'Dermatitis', 'Headache', 'Nausea'), 860],
#  ['Dermatitis', ('Vomiting', 'Rash', 'Headache', 'Nausea'), 860],
#  ['Nausea', ('Vomiting', 'Rash', 'Dermatitis', 'Headache'), 860],
#  ['Nausea', ('Abdominal pain',), 858],
#  ['Abdominal pain', ('Nausea',), 858],
#  ['Dermatitis', ('Dizziness', 'Headache', 'Nausea'), 856],
#  ['Headache', ('Dizziness', 'Dermatitis', 'Nausea'), 856],
#  ['Nausea', ('Dizziness', 'Dermatitis', 'Headache'), 856],
#  ['Diarrhoea', ('Vomiting', 'Rash'), 856],
#  ['Dizziness', ('Dermatitis', 'Headache', 'Nausea'), 856],
#  ['Headache', ('Diarrhoea', 'Vomiting'), 856],
#  ['Vomiting', ('Diarrhoea', 'Headache'), 856],
#  ['Diarrhoea', ('Vomiting', 'Headache'), 856],
#  ['Rash', ('Diarrhoea', 'Vomiting'), 856],
#  ['Vomiting', ('Diarrhoea', 'Rash'), 856],
#  ['Diarrhoea', ('Vomiting', 'Dermatitis', 'Nausea'), 855],
#  ['Nausea', ('Asthenia', 'Vomiting'), 855],
#  ['Nausea', ('Asthenia', 'Headache'), 855],
#  ['Headache', ('Asthenia', 'Nausea'), 855],
#  ['Asthenia', ('Headache', 'Nausea'), 855],
#  ['Nausea', ('Diarrhoea', 'Vomiting', 'Dermatitis'), 855],
#  ['Dermatitis', ('Diarrhoea', 'Vomiting', 'Nausea'), 855],
#  ['Vomiting', ('Diarrhoea', 'Dermatitis', 'Nausea'), 855],
#  ['Vomiting', ('Asthenia', 'Nausea'), 855],
#  ['Asthenia', ('Vomiting', 'Nausea'), 855],
#  ['Dizziness', ('Rash', 'Headache', 'Nausea'), 852],
#  ['Headache', ('Dizziness', 'Rash', 'Nausea'), 852],
#  ['Rash', ('Dizziness', 'Headache', 'Nausea'), 852],
#  ['Nausea', ('Dizziness', 'Rash', 'Headache'), 852],
#  ['Rash', ('Diarrhoea', 'Vomiting', 'Nausea'), 851],
#  ['Nausea', ('Diarrhoea', 'Vomiting', 'Rash'), 851],
#  ['Vomiting', ('Pruritus',), 851],
#  ['Pruritus', ('Vomiting',), 851],
#  ['Vomiting', ('Diarrhoea', 'Rash', 'Nausea'), 851],
#  ['Diarrhoea', ('Vomiting', 'Rash', 'Nausea'), 851],
#  ['Nausea', ('Diarrhoea', 'Vomiting', 'Headache'), 850],
#  ['Headache', ('Diarrhoea', 'Vomiting', 'Nausea'), 850],
#  ['Vomiting', ('Diarrhoea', 'Headache', 'Nausea'), 850],
#  ['Diarrhoea', ('Vomiting', 'Headache', 'Nausea'), 850],
#  ['Dermatitis', ('Diarrhoea', 'Vomiting', 'Rash'), 848],
#  ['Rash', ('Diarrhoea', 'Vomiting', 'Dermatitis'), 848],
#  ['Vomiting', ('Diarrhoea', 'Rash', 'Dermatitis'), 848],
#  ['Diarrhoea', ('Vomiting', 'Rash', 'Dermatitis'), 848],
#  ['Asthenia', ('Dermatitis',), 848],
#  ['Dermatitis', ('Asthenia',), 848],
#  ['Rash', ('Asthenia',), 847],
#  ['Asthenia', ('Rash',), 847],
#  ['Nausea', ('Dizziness', 'Rash', 'Dermatitis', 'Headache'), 846],
#  ['Dizziness', ('Rash', 'Dermatitis', 'Headache', 'Nausea'), 846],
#  ['Headache', ('Dizziness', 'Rash', 'Dermatitis', 'Nausea'), 846],
#  ['Dermatitis', ('Dizziness', 'Rash', 'Headache', 'Nausea'), 846],
#  ['Rash', ('Dizziness', 'Dermatitis', 'Headache', 'Nausea'), 846],
#  ['Dermatitis', ('Hypersensitivity',), 844],
#  ['Hypersensitivity', ('Dermatitis',), 844],
#  ['Vomiting', ('Diarrhoea', 'Rash', 'Dermatitis', 'Nausea'), 843],
#  ['Dermatitis', ('Diarrhoea', 'Vomiting', 'Rash', 'Nausea'), 843],
#  ['Diarrhoea', ('Vomiting', 'Rash', 'Dermatitis', 'Nausea'), 843],
#  ['Pruritus', ('Vomiting', 'Nausea'), 843],
#  ['Rash', ('Diarrhoea', 'Vomiting', 'Dermatitis', 'Nausea'), 843],
#  ['Nausea', ('Diarrhoea', 'Vomiting', 'Rash', 'Dermatitis'), 843],
#  ['Nausea', ('Pruritus', 'Vomiting'), 843],
#  ['Vomiting', ('Pruritus', 'Nausea'), 843],
#  ['Nausea', ('Asthenia', 'Dizziness'), 841],
#  ['Asthenia', ('Dizziness', 'Nausea'), 841],
#  ['Dizziness', ('Asthenia', 'Nausea'), 841],
#  ['Rash', ('Asthenia', 'Dermatitis'), 839],
#  ['Dizziness', ('Diarrhoea', 'Headache'), 839],
#  ['Diarrhoea', ('Dizziness', 'Headache'), 839],
#  ['Asthenia', ('Rash', 'Dermatitis'), 839],
#  ['Dermatitis', ('Dizziness', 'Vomiting'), 839],
#  ['Vomiting', ('Dizziness', 'Dermatitis'), 839],
#  ['Dermatitis', ('Asthenia', 'Rash'), 839],
#  ['Dizziness', ('Vomiting', 'Dermatitis'), 839],
#  ['Headache', ('Diarrhoea', 'Dizziness'), 839],
#  ['Pruritus', ('Dermatitis', 'Nausea'), 836],
#  ['Dermatitis', ('Pruritus', 'Nausea'), 836],
#  ['Nausea', ('Pruritus', 'Dermatitis'), 836],
#  ['Dermatitis', ('Diarrhoea', 'Headache'), 836],
#  ['Diarrhoea', ('Dermatitis', 'Headache'), 836],
#  ['Headache', ('Diarrhoea', 'Dermatitis'), 836],
#  ['Hypersensitivity', ('Rash',), 835],
#  ['Rash', ('Hypersensitivity',), 835],
#  ['Dizziness', ('Vomiting', 'Dermatitis', 'Nausea'), 834],
#  ['Nausea', ('Dizziness', 'Vomiting', 'Dermatitis'), 834],
#  ['Dizziness', ('Vomiting', 'Rash'), 834],
#  ['Vomiting', ('Dizziness', 'Rash'), 834],
#  ['Rash', ('Dizziness', 'Vomiting'), 834],
#  ['Vomiting', ('Dizziness', 'Dermatitis', 'Nausea'), 834],
#  ['Dermatitis', ('Dizziness', 'Vomiting', 'Nausea'), 834],
#  ['Rash', ('Pruritus', 'Nausea'), 833],
#  ['Dizziness', ('Asthenia', 'Headache'), 833],
#  ['Pruritus', ('Rash', 'Nausea'), 833],
#  ['Headache', ('Asthenia', 'Dizziness'), 833],
#  ['Nausea', ('Pruritus', 'Rash'), 833],
#  ['Asthenia', ('Dizziness', 'Headache'), 833],
#  ['Abdominal pain', ('Gastrointestinal pain',), 831],
#  ['Gastrointestinal pain', ('Abdominal pain',), 831],
#  ['Diarrhoea', ('Rash', 'Headache'), 830],
#  ['Rash', ('Diarrhoea', 'Headache'), 830],
#  ['Headache', ('Diarrhoea', 'Rash'), 830],
#  ['Dizziness', ('Vomiting', 'Rash', 'Nausea'), 829],
#  ['Vomiting', ('Dizziness', 'Rash', 'Nausea'), 829],
#  ['Rash', ('Dizziness', 'Vomiting', 'Nausea'), 829],
#  ['Dermatitis', ('Dizziness', 'Vomiting', 'Rash'), 829],
#  ['Vomiting', ('Dizziness', 'Rash', 'Dermatitis'), 829],
#  ['Dizziness', ('Vomiting', 'Rash', 'Dermatitis'), 829],
#  ['Nausea', ('Dizziness', 'Vomiting', 'Rash'), 829],
#  ['Rash', ('Dizziness', 'Vomiting', 'Dermatitis'), 829],
#  ['Hypersensitivity', ('Rash', 'Dermatitis'), 827],
#  ['Rash', ('Hypersensitivity', 'Dermatitis'), 827],
#  ['Dermatitis', ('Hypersensitivity', 'Rash'), 827],
#  ['Headache', ('Diarrhoea', 'Rash', 'Dermatitis'), 826],
#  ['Dermatitis', ('Diarrhoea', 'Rash', 'Headache'), 826],
#  ['Rash', ('Diarrhoea', 'Dermatitis', 'Headache'), 826],
#  ['Diarrhoea', ('Rash', 'Dermatitis', 'Headache'), 826],
#  ['Dermatitis', ('Pruritus', 'Rash', 'Nausea'), 825],
#  ['Rash', ('Pruritus', 'Dermatitis', 'Nausea'), 825],
#  ['Pruritus', ('Rash', 'Dermatitis', 'Nausea'), 825],
#  ['Nausea', ('Pruritus', 'Rash', 'Dermatitis'), 825],
#  ['Pruritus', ('Headache', 'Nausea'), 825],
#  ['Headache', ('Pruritus', 'Nausea'), 825],
#  ['Nausea', ('Pruritus', 'Headache'), 825],
#  ['Diarrhoea', ('Asthenia',), 824],
#  ['Asthenia', ('Diarrhoea',), 824],
#  ['Pruritus', ('Dizziness',), 824],
#  ['Abdominal pain', ('Vomiting',), 824],
#  ['Vomiting', ('Abdominal pain',), 824],
#  ['Nausea', ('Asthenia', 'Dermatitis'), 824],
#  ['Nausea', ('Dizziness', 'Vomiting', 'Rash', 'Dermatitis'), 824],
#  ['Dizziness', ('Pruritus',), 824],
#  ['Rash', ('Dizziness', 'Vomiting', 'Dermatitis', 'Nausea'), 824],
#  ['Vomiting', ('Dizziness', 'Rash', 'Dermatitis', 'Nausea'), 824],
#  ['Asthenia', ('Dermatitis', 'Nausea'), 824],
#  ['Dizziness', ('Vomiting', 'Rash', 'Dermatitis', 'Nausea'), 824],
#  ['Dermatitis', ('Asthenia', 'Nausea'), 824],
#  ['Dermatitis', ('Dizziness', 'Vomiting', 'Rash', 'Nausea'), 824],
#  ['Asthenia', ('Rash', 'Nausea'), 822],
#  ['Rash', ('Asthenia', 'Nausea'), 822],
#  ['Nausea', ('Asthenia', 'Rash'), 822],
#  ['Dermatitis', ('Diarrhoea', 'Headache', 'Nausea'), 821],
#  ['Diarrhoea', ('Dermatitis', 'Headache', 'Nausea'), 821],
#  ['Headache', ('Diarrhoea', 'Dermatitis', 'Nausea'), 821],
#  ['Hypersensitivity', ('Headache',), 821],
#  ['Headache', ('Hypersensitivity',), 821],
#  ['Nausea', ('Diarrhoea', 'Dermatitis', 'Headache'), 821],
#  ['Nausea', ('Abdominal pain', 'Vomiting'), 818],
#  ['Abdominal pain', ('Vomiting', 'Nausea'), 818],
#  ['Vomiting', ('Abdominal pain', 'Nausea'), 818],
#  ['Nausea', ('Diarrhoea', 'Dizziness', 'Headache'), 817],
#  ['Diarrhoea', ('Dizziness', 'Headache', 'Nausea'), 817],
#  ['Headache', ('Diarrhoea', 'Dizziness', 'Nausea'), 817],
#  ['Dizziness', ('Diarrhoea', 'Headache', 'Nausea'), 817],
#  ['Asthenia', ('Rash', 'Dermatitis', 'Nausea'), 815],
#  ['Nausea', ('Asthenia', 'Rash', 'Dermatitis'), 815],
#  ['Dermatitis', ('Asthenia', 'Rash', 'Nausea'), 815],
#  ['Rash', ('Asthenia', 'Dermatitis', 'Nausea'), 815],
#  ['Hypersensitivity', ('Vomiting',), 815],
#  ['Vomiting', ('Hypersensitivity',), 815],
#  ['Headache', ('Diarrhoea', 'Rash', 'Nausea'), 814],
#  ['Vomiting', ('Diarrhoea', 'Dizziness'), 814],
#  ['Rash', ('Diarrhoea', 'Headache', 'Nausea'), 814],
#  ['Dizziness', ('Diarrhoea', 'Vomiting'), 814],
#  ['Nausea', ('Diarrhoea', 'Rash', 'Headache'), 814],
#  ['Diarrhoea', ('Rash', 'Headache', 'Nausea'), 814],
#  ['Diarrhoea', ('Dizziness', 'Vomiting'), 814],
#  ['Nausea', ('Gastrointestinal pain',), 813],
#  ['Gastrointestinal pain', ('Nausea',), 813],
#  ['Nausea', ('Diarrhoea', 'Rash', 'Dermatitis', 'Headache'), 811],
#  ['Rash', ('Diarrhoea', 'Dermatitis', 'Headache', 'Nausea'), 811],
#  ['Diarrhoea', ('Rash', 'Dermatitis', 'Headache', 'Nausea'), 811],
#  ['Dermatitis', ('Diarrhoea', 'Rash', 'Headache', 'Nausea'), 811],
#  ['Headache', ('Diarrhoea', 'Rash', 'Dermatitis', 'Nausea'), 811],
#  ['Diarrhoea', ('Dizziness', 'Vomiting', 'Nausea'), 810],
#  ['Vomiting', ('Diarrhoea', 'Dizziness', 'Nausea'), 810],
#  ['Dizziness', ('Diarrhoea', 'Vomiting', 'Nausea'), 810],
#  ['Nausea', ('Diarrhoea', 'Dizziness', 'Vomiting'), 810],
#  ['Hypersensitivity', ('Vomiting', 'Nausea'), 808],
#  ['Vomiting', ('Hypersensitivity', 'Nausea'), 808],
#  ['Nausea', ('Hypersensitivity', 'Vomiting'), 808],
#  ['Nausea', ('Gastrointestinal pain', 'Abdominal pain'), 807],
#  ['Nausea', ('Urticaria',), 807],
#  ['Urticaria', ('Nausea',), 807],
#  ['Gastrointestinal pain', ('Abdominal pain', 'Nausea'), 807],
#  ['Abdominal pain', ('Gastrointestinal pain', 'Nausea'), 807],
#  ['Abdominal pain', ('Headache',), 805],
#  ['Headache', ('Abdominal pain',), 805],
#  ['Abdominal pain', ('Diarrhoea',), 805],
#  ['Diarrhoea', ('Abdominal pain',), 805],
#  ['Asthenia', ('Diarrhoea', 'Nausea'), 804],
#  ['Diarrhoea', ('Asthenia', 'Nausea'), 804],
#  ['Nausea', ('Asthenia', 'Diarrhoea'), 804],
#  ['Vomiting', ('Asthenia', 'Headache'), 799],
#  ['Asthenia', ('Vomiting', 'Headache'), 799],
#  ['Headache', ('Asthenia', 'Vomiting'), 799],
#  ['Nausea', ('Asthenia', 'Dizziness', 'Headache'), 799],
#  ['Asthenia', ('Dizziness', 'Headache', 'Nausea'), 799],
#  ['Dizziness', ('Asthenia', 'Headache', 'Nausea'), 799],
#  ['Headache', ('Asthenia', 'Dizziness', 'Nausea'), 799],
#  ['Vomiting', ('Dizziness', 'Dermatitis', 'Headache'), 798],
#  ['Dermatitis', ('Dizziness', 'Vomiting', 'Headache'), 798],
#  ['Headache', ('Dizziness', 'Vomiting', 'Dermatitis'), 798],
#  ['Dizziness', ('Vomiting', 'Dermatitis', 'Headache'), 798],
#  ['Dermatitis', ('Asthenia', 'Headache'), 796],
#  ['Asthenia', ('Dermatitis', 'Headache'), 796],
#  ['Body temperature increased', ('Nausea',), 796],
#  ['Headache', ('Asthenia', 'Dermatitis'), 796],
#  ['Nausea', ('Body temperature increased',), 796],
#  ['Dermatitis', ('Dizziness', 'Vomiting', 'Headache', 'Nausea'), 794],
#  ['Dizziness', ('Vomiting', 'Dermatitis', 'Headache', 'Nausea'), 794],
#  ['Headache', ('Dizziness', 'Vomiting', 'Dermatitis', 'Nausea'), 794],
#  ['Rash', ('Asthenia', 'Headache'), 794],
#  ['Asthenia', ('Rash', 'Headache'), 794],
#  ['Headache', ('Asthenia', 'Rash'), 794],
#  ['Vomiting', ('Dizziness', 'Dermatitis', 'Headache', 'Nausea'), 794],
#  ['Nausea', ('Dizziness', 'Vomiting', 'Dermatitis', 'Headache'), 794],
#  ['Nausea', ('Asthenia', 'Vomiting', 'Headache'), 793],
#  ['Headache', ('Dizziness', 'Vomiting', 'Rash'), 793],
#  ['Asthenia', ('Vomiting', 'Headache', 'Nausea'), 793],
#  ['Vomiting', ('Asthenia', 'Headache', 'Nausea'), 793],
#  ['Headache', ('Asthenia', 'Vomiting', 'Nausea'), 793],
#  ['Dizziness', ('Vomiting', 'Rash', 'Headache'), 793],
#  ['Pruritus', ('Dizziness', 'Nausea'), 793],
#  ['Rash', ('Dizziness', 'Vomiting', 'Headache'), 793],
#  ['Vomiting', ('Dizziness', 'Rash', 'Headache'), 793],
#  ['Nausea', ('Pruritus', 'Dizziness'), 793],
#  ['Dizziness', ('Pruritus', 'Nausea'), 793],
#  ['Dizziness', ('Diarrhoea', 'Dermatitis'), 792],
#  ['Diarrhoea', ('Dizziness', 'Dermatitis'), 792],
#  ['Dermatitis', ('Diarrhoea', 'Dizziness'), 792],
#  ['Dermatitis', ('Pruritus', 'Headache'), 790],
#  ['Pruritus', ('Dermatitis', 'Headache'), 790],
#  ['Headache', ('Pruritus', 'Dermatitis'), 790],
#  ['Diarrhoea', ('Pruritus',), 790],
#  ['Pruritus', ('Diarrhoea',), 790],
#  ['Rash', ('Dizziness', 'Vomiting', 'Headache', 'Nausea'), 789],
#  ['Headache', ('Dizziness', 'Vomiting', 'Rash', 'Nausea'), 789],
#  ['Dermatitis', ('Abdominal pain',), 789],
#  ['Nausea', ('Dizziness', 'Vomiting', 'Rash', 'Headache'), 789],
#  ['Pruritus', ('Vomiting', 'Dermatitis'), 789],
#  ['Headache', ('Dizziness', 'Vomiting', 'Rash', 'Dermatitis'), 789],
#  ['Dermatitis', ('Dizziness', 'Vomiting', 'Rash', 'Headache'), 789],
#  ['Rash', ('Dizziness', 'Vomiting', 'Dermatitis', 'Headache'), 789],
#  ['Vomiting', ('Dizziness', 'Rash', 'Dermatitis', 'Headache'), 789],
#  ['Dizziness', ('Vomiting', 'Rash', 'Dermatitis', 'Headache'), 789],
#  ['Vomiting', ('Pruritus', 'Dermatitis'), 789],
#  ['Vomiting', ('Dizziness', 'Rash', 'Headache', 'Nausea'), 789],
#  ['Dizziness', ('Vomiting', 'Rash', 'Headache', 'Nausea'), 789],
#  ['Dermatitis', ('Pruritus', 'Vomiting'), 789],
#  ['Abdominal pain', ('Dermatitis',), 789],
#  ['Dermatitis', ('Diarrhoea', 'Vomiting', 'Headache'), 788],
#  ['Rash', ('Asthenia', 'Dermatitis', 'Headache'), 788],
#  ['Asthenia', ('Rash', 'Dermatitis', 'Headache'), 788],
#  ['Headache', ('Diarrhoea', 'Vomiting', 'Dermatitis'), 788],
#  ['Vomiting', ('Diarrhoea', 'Dermatitis', 'Headache'), 788],
#  ['Diarrhoea', ('Vomiting', 'Dermatitis', 'Headache'), 788],
#  ['Dermatitis', ('Asthenia', 'Rash', 'Headache'), 788],
#  ['Headache', ('Asthenia', 'Rash', 'Dermatitis'), 788],
#  ['Nausea', ('Hypersensitivity', 'Dermatitis'), 788],
#  ['Dermatitis', ('Hypersensitivity', 'Nausea'), 788],
#  ['Hypersensitivity', ('Dermatitis', 'Nausea'), 788],
#  ['Nausea', ('Abdominal pain', 'Diarrhoea'), 786],
#  ['Abdominal pain', ('Rash',), 786],
#  ['Rash', ('Abdominal pain',), 786],
#  ['Abdominal pain', ('Diarrhoea', 'Nausea'), 786],
#  ['Diarrhoea', ('Abdominal pain', 'Nausea'), 786],
#  ['Vomiting', ('Asthenia', 'Dizziness'), 786],
#  ['Dizziness', ('Asthenia', 'Vomiting'), 786],
#  ['Asthenia', ('Dizziness', 'Vomiting'), 786],
#  ['Rash', ('Dizziness', 'Vomiting', 'Dermatitis', 'Headache', 'Nausea'), 785],
#  ['Dizziness', ('Vomiting', 'Rash', 'Dermatitis', 'Headache', 'Nausea'), 785],
#  ['Vomiting', ('Dizziness', 'Rash', 'Dermatitis', 'Headache', 'Nausea'), 785],
#  ['Dermatitis', ('Dizziness', 'Vomiting', 'Rash', 'Headache', 'Nausea'), 785],
#  ['Headache', ('Dizziness', 'Vomiting', 'Rash', 'Dermatitis', 'Nausea'), 785],
#  ['Nausea', ('Dizziness', 'Vomiting', 'Rash', 'Dermatitis', 'Headache'), 785],
#  ['Diarrhoea', ('Dizziness', 'Rash'), 785],
#  ['Rash', ('Diarrhoea', 'Dizziness'), 785],
#  ['Headache', ('Pruritus', 'Rash'), 785],
#  ['Rash', ('Pruritus', 'Headache'), 785],
#  ['Pruritus', ('Rash', 'Headache'), 785],
#  ['Dizziness', ('Diarrhoea', 'Rash'), 785],
#  ['Nausea', ('Diarrhoea', 'Vomiting', 'Dermatitis', 'Headache'), 784],
#  ['Diarrhoea', ('Vomiting', 'Dermatitis', 'Headache', 'Nausea'), 784],
#  ['Nausea', ('Hypersensitivity', 'Headache'), 784],
#  ['Vomiting', ('Diarrhoea', 'Dermatitis', 'Headache', 'Nausea'), 784],
#  ['Headache', ('Hypersensitivity', 'Nausea'), 784],
#  ['Headache', ('Diarrhoea', 'Vomiting', 'Dermatitis', 'Nausea'), 784],
#  ['Nausea', ('Abdominal pain', 'Headache'), 784],
#  ['Headache', ('Abdominal pain', 'Nausea'), 784],
#  ['Abdominal pain', ('Headache', 'Nausea'), 784],
#  ['Dermatitis', ('Diarrhoea', 'Vomiting', 'Headache', 'Nausea'), 784],
#  ['Hypersensitivity', ('Headache', 'Nausea'), 784],
#  ['Gastrointestinal pain', ('Vomiting',), 783],
#  ['Vomiting', ('Gastrointestinal pain',), 783],
#  ['Dermatitis', ('Diarrhoea', 'Dizziness', 'Rash'), 782],
#  ['Rash', ('Diarrhoea', 'Dizziness', 'Dermatitis'), 782],
#  ['Dizziness', ('Diarrhoea', 'Rash', 'Dermatitis'), 782],
#  ['Diarrhoea', ('Dizziness', 'Rash', 'Dermatitis'), 782],
#  ['Vomiting', ('Pruritus', 'Rash'), 782],
#  ['Diarrhoea', ('Vomiting', 'Rash', 'Headache'), 782],
#  ['Hypersensitivity', ('Rash', 'Nausea'), 782],
#  ['Rash', ('Hypersensitivity', 'Nausea'), 782],
#  ['Nausea', ('Hypersensitivity', 'Rash'), 782],
#  ['Vomiting', ('Diarrhoea', 'Rash', 'Headache'), 782],
#  ['Rash', ('Diarrhoea', 'Vomiting', 'Headache'), 782],
#  ['Pruritus', ('Vomiting', 'Rash'), 782],
#  ['Headache', ('Diarrhoea', 'Vomiting', 'Rash'), 782],
#  ['Rash', ('Pruritus', 'Vomiting'), 782],
#  ['Nausea', ('Pruritus', 'Vomiting', 'Dermatitis'), 781],
#  ['Dermatitis', ('Pruritus', 'Vomiting', 'Nausea'), 781],
#  ['Vomiting', ('Pruritus', 'Dermatitis', 'Nausea'), 781],
#  ['Pruritus', ('Vomiting', 'Dermatitis', 'Nausea'), 781],
#  ['Headache', ('Pruritus', 'Dizziness'), 781],
#  ['Dizziness', ('Pruritus', 'Headache'), 781],
#  ['Pruritus', ('Dizziness', 'Headache'), 781],
#  ['Dermatitis', ('Diarrhoea', 'Dizziness', 'Nausea'), 780],
#  ['Nausea', ('Asthenia', 'Dizziness', 'Vomiting'), 780],
#  ['Rash', ('Abdominal pain', 'Dermatitis'), 780],
#  ['Vomiting', ('Asthenia', 'Dizziness', 'Nausea'), 780],
#  ['Abdominal pain', ('Rash', 'Dermatitis'), 780],
#  ['Dizziness', ('Asthenia', 'Vomiting', 'Nausea'), 780],
#  ['Nausea', ('Diarrhoea', 'Dizziness', 'Dermatitis'), 780],
#  ['Asthenia', ('Dizziness', 'Vomiting', 'Nausea'), 780],
#  ['Dermatitis', ('Abdominal pain', 'Rash'), 780],
#  ['Dizziness', ('Diarrhoea', 'Dermatitis', 'Nausea'), 780],
#  ['Diarrhoea', ('Dizziness', 'Dermatitis', 'Nausea'), 780],
#  ['Dermatitis', ('Diarrhoea', 'Vomiting', 'Rash', 'Headache'), 779],
#  ['Hypersensitivity', ('Dizziness',), 779],
#  ['Dizziness', ('Hypersensitivity',), 779],
#  ['Nausea', ('Gastrointestinal pain', 'Vomiting'), 779],
#  ['Vomiting', ('Gastrointestinal pain', 'Nausea'), 779],
#  ['Gastrointestinal pain', ('Vomiting', 'Nausea'), 779],
#  ['Rash', ('Diarrhoea', 'Vomiting', 'Dermatitis', 'Headache'), 779],
#  ['Headache', ('Diarrhoea', 'Vomiting', 'Rash', 'Dermatitis'), 779],
#  ['Asthenia', ('Vomiting', 'Dermatitis'), 779],
#  ['Vomiting', ('Asthenia', 'Dermatitis'), 779],
#  ['Dermatitis', ('Asthenia', 'Vomiting'), 779],
#  ['Diarrhoea', ('Vomiting', 'Rash', 'Dermatitis', 'Headache'), 779],
#  ['Vomiting', ('Diarrhoea', 'Rash', 'Dermatitis', 'Headache'), 779],
#  ['Dermatitis', ('Asthenia', 'Dizziness'), 778],
#  ['Headache', ('Diarrhoea', 'Vomiting', 'Rash', 'Nausea'), 778],
#  ['Rash', ('Diarrhoea', 'Vomiting', 'Headache', 'Nausea'), 778],
#  ['Vomiting', ('Diarrhoea', 'Rash', 'Headache', 'Nausea'), 778],
#  ['Nausea', ('Diarrhoea', 'Vomiting', 'Rash', 'Headache'), 778],
#  ['Dizziness', ('Asthenia', 'Dermatitis'), 778],
#  ['Diarrhoea', ('Vomiting', 'Rash', 'Headache', 'Nausea'), 778],
#  ['Rash', ('Pruritus', 'Dermatitis', 'Headache'), 778],
#  ['Dermatitis', ('Pruritus', 'Rash', 'Headache'), 778],
#  ['Headache', ('Pruritus', 'Rash', 'Dermatitis'), 778],
#  ['Asthenia', ('Dizziness', 'Dermatitis'), 778],
#  ['Pruritus', ('Rash', 'Dermatitis', 'Headache'), 778],
#  ['Dermatitis', ('Pruritus', 'Vomiting', 'Rash'), 777],
#  ['Vomiting', ('Gastrointestinal pain', 'Abdominal pain'), 777],
#  ['Abdominal pain', ('Gastrointestinal pain', 'Vomiting'), 777],
#  ['Vomiting', ('Pruritus', 'Rash', 'Dermatitis'), 777],
#  ['Pruritus', ('Vomiting', 'Rash', 'Dermatitis'), 777],
#  ['Rash', ('Pruritus', 'Vomiting', 'Dermatitis'), 777],
#  ['Gastrointestinal pain', ('Abdominal pain', 'Vomiting'), 777],
#  ['Asthenia', ('Vomiting', 'Rash'), 776],
#  ['Rash', ('Asthenia', 'Vomiting'), 776],
#  ['Asthenia', ('Diarrhoea', 'Headache'), 776],
#  ['Diarrhoea', ('Asthenia', 'Headache'), 776],
#  ['Diarrhoea', ('Dizziness', 'Vomiting', 'Headache'), 776],
#  ['Vomiting', ('Asthenia', 'Rash'), 776],
#  ['Headache', ('Asthenia', 'Diarrhoea'), 776],
#  ['Headache', ('Diarrhoea', 'Dizziness', 'Vomiting'), 776],
#  ['Vomiting', ('Diarrhoea', 'Dizziness', 'Headache'), 776],
#  ['Dermatitis', ('Urticaria',), 776],
#  ['Urticaria', ('Dermatitis',), 776],
#  ['Dizziness', ('Diarrhoea', 'Vomiting', 'Headache'), 776],
#  ['Headache', ('Diarrhoea', 'Vomiting', 'Rash', 'Dermatitis', 'Nausea'), 775],
#  ['Dermatitis', ('Diarrhoea', 'Vomiting', 'Rash', 'Headache', 'Nausea'), 775],
#  ['Nausea', ('Pruritus', 'Vomiting', 'Rash'), 775],
#  ['Diarrhoea', ('Vomiting', 'Rash', 'Dermatitis', 'Headache', 'Nausea'), 775],
#  ['Asthenia', ('Dermatitis', 'Headache', 'Nausea'), 775],
#  ['Rash', ('Pruritus', 'Vomiting', 'Nausea'), 775],
#  ['Nausea', ('Diarrhoea', 'Vomiting', 'Rash', 'Dermatitis', 'Headache'), 775],
#  ['Rash', ('Asthenia', 'Dizziness'), 775],
#  ['Rash', ('Diarrhoea', 'Vomiting', 'Dermatitis', 'Headache', 'Nausea'), 775],
#  ['Asthenia', ('Dizziness', 'Rash'), 775],
#  ['Dermatitis', ('Asthenia', 'Headache', 'Nausea'), 775],
#  ['Headache', ('Asthenia', 'Dermatitis', 'Nausea'), 775],
#  ['Nausea', ('Asthenia', 'Dermatitis', 'Headache'), 775],
#  ['Pruritus', ('Vomiting', 'Rash', 'Nausea'), 775],
#  ['Vomiting', ('Pruritus', 'Rash', 'Nausea'), 775],
#  ['Vomiting', ('Diarrhoea', 'Rash', 'Dermatitis', 'Headache', 'Nausea'), 775],
#  ['Dizziness', ('Asthenia', 'Rash'), 775],
#  ['Dermatitis', ('Hypersensitivity', 'Rash', 'Nausea'), 774],
#  ['Urticaria', ('Rash',), 774],
#  ['Rash', ('Urticaria',), 774],
#  ['Rash', ('Hypersensitivity', 'Dermatitis', 'Nausea'), 774],
#  ['Nausea', ('Hypersensitivity', 'Rash', 'Dermatitis'), 774],
#  ['Hypersensitivity', ('Rash', 'Dermatitis', 'Nausea'), 774],
#  ['Diarrhoea', ('Pruritus', 'Nausea'), 774],
#  ['Nausea', ('Pruritus', 'Diarrhoea'), 774],
#  ['Pruritus', ('Diarrhoea', 'Nausea'), 774],
#  ['Abdominal pain', ('Dermatitis', 'Nausea'), 773],
#  ['Gastrointestinal pain', ('Headache',), 773],
#  ['Headache', ('Gastrointestinal pain',), 773],
#  ['Nausea', ('Abdominal pain', 'Dermatitis'), 773],
#  ['Asthenia', ('Vomiting', 'Dermatitis', 'Nausea'), 773],
#  ['Vomiting', ('Asthenia', 'Dermatitis', 'Nausea'), 773],
#  ['Dermatitis', ('Asthenia', 'Vomiting', 'Nausea'), 773],
#  ['Gastrointestinal pain', ('Abdominal pain', 'Vomiting', 'Nausea'), 773],
#  ['Abdominal pain', ('Gastrointestinal pain', 'Vomiting', 'Nausea'), 773],
#  ['Diarrhoea', ('Dizziness', 'Rash', 'Nausea'), 773],
#  ['Dizziness', ('Diarrhoea', 'Rash', 'Nausea'), 773],
#  ['Rash', ('Diarrhoea', 'Dizziness', 'Nausea'), 773],
#  ['Nausea', ('Diarrhoea', 'Dizziness', 'Rash'), 773],
#  ['Nausea', ('Asthenia', 'Vomiting', 'Dermatitis'), 773],
#  ['Vomiting', ('Gastrointestinal pain', 'Abdominal pain', 'Nausea'), 773],
#  ['Dermatitis', ('Abdominal pain', 'Nausea'), 773],
#  ['Headache', ('Asthenia', 'Rash', 'Nausea'), 772],
#  ['Nausea', ('Asthenia', 'Rash', 'Headache'), 772],
#  ['Headache', ('Diarrhoea', 'Dizziness', 'Vomiting', 'Nausea'), 772],
#  ['Vomiting', ('Diarrhoea', 'Dizziness', 'Headache', 'Nausea'), 772],
#  ['Dizziness', ('Diarrhoea', 'Vomiting', 'Headache', 'Nausea'), 772],
#  ['Diarrhoea', ('Dizziness', 'Vomiting', 'Headache', 'Nausea'), 772],
#  ['Rash', ('Asthenia', 'Headache', 'Nausea'), 772],
#  ['Asthenia', ('Rash', 'Headache', 'Nausea'), 772],
#  ['Rash', ('Abdominal pain', 'Nausea'), 771],
#  ['Body temperature increased', ('Vomiting',), 771],
#  ['Vomiting', ('Body temperature increased',), 771],
#  ['Abdominal pain', ('Rash', 'Nausea'), 771],
#  ['Nausea', ('Abdominal pain', 'Rash'), 771],
#  ['Asthenia', ('Diarrhoea', 'Vomiting'), 770],
#  ['Pruritus', ('Vomiting', 'Rash', 'Dermatitis', 'Nausea'), 770],
#  ['Dizziness', ('Diarrhoea', 'Rash', 'Dermatitis', 'Nausea'), 770],
#  ['Diarrhoea', ('Dizziness', 'Rash', 'Dermatitis', 'Nausea'), 770],
#  ['Nausea', ('Diarrhoea', 'Dizziness', 'Rash', 'Dermatitis'), 770],
#  ['Rash', ('Diarrhoea', 'Dizziness', 'Dermatitis', 'Nausea'), 770],
#  ['Rash', ('Pruritus', 'Vomiting', 'Dermatitis', 'Nausea'), 770],
#  ['Vomiting', ('Pruritus', 'Rash', 'Dermatitis', 'Nausea'), 770],
#  ['Vomiting', ('Asthenia', 'Rash', 'Nausea'), 770],
#  ['Rash', ('Asthenia', 'Vomiting', 'Nausea'), 770],
#  ['Asthenia', ('Vomiting', 'Rash', 'Dermatitis'), 770],
#  ['Asthenia', ('Vomiting', 'Rash', 'Nausea'), 770],
#  ['Rash', ('Asthenia', 'Vomiting', 'Dermatitis'), 770],
#  ['Vomiting', ('Asthenia', 'Rash', 'Dermatitis'), 770],
#  ['Diarrhoea', ('Asthenia', 'Vomiting'), 770],
#  ['Rash', ('Asthenia', 'Dizziness', 'Dermatitis'), 770],
#  ['Dizziness', ('Asthenia', 'Rash', 'Dermatitis'), 770],
#  ['Asthenia', ('Dizziness', 'Rash', 'Dermatitis'), 770],
#  ['Vomiting', ('Asthenia', 'Diarrhoea'), 770],
#  ['Pruritus', ('Vomiting', 'Headache'), 769],
#  ['Vomiting', ('Pruritus', 'Headache'), 769],
#  ['Headache', ('Pruritus', 'Vomiting'), 769],
#  ['Gastrointestinal pain', ('Abdominal pain', 'Headache'), 768],
#  ['Headache', ('Gastrointestinal pain', 'Abdominal pain'), 768],
#  ['Nausea', ('Asthenia', 'Rash', 'Dermatitis', 'Headache'), 767],
#  ['Asthenia', ('Rash', 'Dermatitis', 'Headache', 'Nausea'), 767],
#  ['Headache', ('Asthenia', 'Rash', 'Dermatitis', 'Nausea'), 767],
#  ['Fatigue', ('Asthenia',), 766],
#  ['Urticaria', ('Rash', 'Dermatitis'), 766],
#  ['Gastrointestinal pain', ('Diarrhoea',), 766],
#  ['Diarrhoea', ('Gastrointestinal pain',), 766],
#  ['Abdominal pain', ('Rash', 'Dermatitis', 'Nausea'), 765],
#  ['Vomiting', ('Asthenia', 'Diarrhoea', 'Nausea'), 765],
#  ['Nausea', ('Abdominal pain', 'Rash', 'Dermatitis'), 765],
#  ['Diarrhoea', ('Asthenia', 'Vomiting', 'Nausea'), 765],
#  ['Asthenia', ('Diarrhoea', 'Vomiting', 'Nausea'), 765],
#  ['Vomiting', ('Pruritus', 'Headache', 'Nausea'), 765],
#  ['Pruritus', ('Vomiting', 'Headache', 'Nausea'), 765],
#  ['Headache', ('Pruritus', 'Vomiting', 'Nausea'), 765],
#  ['Body temperature increased', ('Vomiting', 'Nausea'), 764],
#  ['Vomiting', ('Asthenia', 'Rash', 'Dermatitis', 'Nausea'), 764],
#  ['Asthenia', ('Vomiting', 'Rash', 'Dermatitis', 'Nausea'), 764],
#  ['Vomiting', ('Body temperature increased', 'Nausea'), 764],
#  ['Abdominal pain', ('Diarrhoea', 'Vomiting'), 763],
#  ['Abdominal pain', ('Dizziness',), 763],
#  ['Vomiting', ('Abdominal pain', 'Diarrhoea'), 763],
#  ['Diarrhoea', ('Abdominal pain', 'Vomiting'), 763],
#  ['Dizziness', ('Abdominal pain',), 763],
#  ['Dermatitis', ('Pruritus', 'Dizziness'), 761],
#  ['Dizziness', ('Pruritus', 'Dermatitis'), 761],
#  ['Pruritus', ('Dizziness', 'Dermatitis'), 761],
#  ['Diarrhoea', ('Gastrointestinal pain', 'Abdominal pain'), 760],
#  ['Gastrointestinal pain', ('Abdominal pain', 'Diarrhoea'), 760],
#  ['Pruritus', ('Dermatitis', 'Headache', 'Nausea'), 759],
#  ['Gastrointestinal pain', ('Dermatitis',), 759],
#  ['Dermatitis', ('Pruritus', 'Headache', 'Nausea'), 759],
#  ['Nausea', ('Pruritus', 'Dermatitis', 'Headache'), 759],
#  ['Dermatitis', ('Gastrointestinal pain',), 759],
#  ['Diarrhoea', ('Dizziness', 'Dermatitis', 'Headache'), 759],
#  ['Dizziness', ('Diarrhoea', 'Dermatitis', 'Headache'), 759],
#  ['Dermatitis', ('Diarrhoea', 'Dizziness', 'Headache'), 759],
#  ['Headache', ('Diarrhoea', 'Dizziness', 'Dermatitis'), 759],
#  ['Headache', ('Pruritus', 'Dermatitis', 'Nausea'), 759],
#  ['Asthenia', ('Dizziness', 'Dermatitis', 'Nausea'), 758],
#  ['Dizziness', ('Asthenia', 'Dermatitis', 'Nausea'), 758],
#  ['Dermatitis', ('Asthenia', 'Dizziness', 'Nausea'), 758],
#  ['Nausea', ('Asthenia', 'Dizziness', 'Dermatitis'), 758],
#  ['Asthenia', ('Diarrhoea', 'Headache', 'Nausea'), 757],
#  ['Gastrointestinal pain', ('Rash',), 757],
#  ['Diarrhoea', ('Asthenia', 'Headache', 'Nausea'), 757],
#  ['Asthenia', ('Diarrhoea', 'Dizziness'), 757],
#  ['Rash', ('Gastrointestinal pain',), 757],
#  ['Diarrhoea', ('Asthenia', 'Dizziness'), 757],
#  ['Dizziness', ('Asthenia', 'Diarrhoea'), 757],
#  ['Rash', ('Pruritus', 'Dizziness'), 757],
#  ['Dizziness', ('Pruritus', 'Rash'), 757],
#  ['Pruritus', ('Dizziness', 'Rash'), 757],
#  ['Diarrhoea', ('Abdominal pain', 'Vomiting', 'Nausea'), 757],
#  ['Vomiting', ('Abdominal pain', 'Diarrhoea', 'Nausea'), 757],
#  ['Headache', ('Asthenia', 'Diarrhoea', 'Nausea'), 757],
#  ['Abdominal pain', ('Diarrhoea', 'Vomiting', 'Nausea'), 757],
#  ['Pruritus', ('Asthenia',), 756],
#  ['Asthenia', ('Pruritus',), 756],
#  ['Abdominal pain', ('Vomiting', 'Headache'), 755],
#  ['Headache', ('Pruritus', 'Rash', 'Nausea'), 755],
#  ['Nausea', ('Pruritus', 'Rash', 'Headache'), 755],
#  ['Vomiting', ('Abdominal pain', 'Headache'), 755],
#  ['Pruritus', ('Rash', 'Headache', 'Nausea'), 755],
#  ['Headache', ('Abdominal pain', 'Vomiting'), 755],
#  ['Rash', ('Pruritus', 'Headache', 'Nausea'), 755],
#  ['Gastrointestinal pain', ('Headache', 'Nausea'), 754],
#  ['Headache', ('Gastrointestinal pain', 'Nausea'), 754],
#  ['Nausea', ('Pruritus', 'Dizziness', 'Headache'), 754],
#  ['Headache', ('Pruritus', 'Dizziness', 'Nausea'), 754],
#  ['Asthenia', ('Dizziness', 'Rash', 'Nausea'), 754],
#  ['Dizziness', ('Pruritus', 'Headache', 'Nausea'), 754],
#  ['Dizziness', ('Asthenia', 'Rash', 'Nausea'), 754],
#  ['Rash', ('Asthenia', 'Dizziness', 'Nausea'), 754],
#  ['Pruritus', ('Dizziness', 'Headache', 'Nausea'), 754],
#  ['Gastrointestinal pain', ('Abdominal pain', 'Dermatitis'), 754],
#  ['Dermatitis', ('Gastrointestinal pain', 'Abdominal pain'), 754],
#  ['Dermatitis', ('Asthenia', 'Diarrhoea'), 753],
#  ['Diarrhoea', ('Asthenia', 'Dermatitis'), 753],
#  ['Asthenia', ('Diarrhoea', 'Dermatitis'), 753],
#  ['Gastrointestinal pain', ('Abdominal pain', 'Rash'), 752],
#  ['Gastrointestinal disorder', ('Nausea',), 752],
#  ['Diarrhoea', ('Dizziness', 'Rash', 'Headache'), 752],
#  ['Gastrointestinal pain', ('Rash', 'Dermatitis'), 752],
#  ['Nausea', ('Gastrointestinal disorder',), 752],
#  ['Dizziness', ('Diarrhoea', 'Rash', 'Headache'), 752],
#  ['Rash', ('Diarrhoea', 'Dizziness', 'Headache'), 752],
#  ['Headache', ('Diarrhoea', 'Dizziness', 'Rash'), 752],
#  ['Rash', ('Gastrointestinal pain', 'Abdominal pain'), 752],
#  ['Vomiting', ('Urticaria',), 751],
#  ['Urticaria', ('Vomiting',), 751],
#  ['Hypersensitivity', ('Dizziness', 'Nausea'), 751],
#  ['Dizziness', ('Pruritus', 'Rash', 'Dermatitis'), 751],
#  ['Dizziness', ('Hypersensitivity', 'Nausea'), 751],
#  ['Nausea', ('Hypersensitivity', 'Dizziness'), 751],
#  ['Pruritus', ('Dizziness', 'Rash', 'Dermatitis'), 751],
#  ['Nausea', ('Feeling abnormal',), 750],
#  ['Headache', ('Abdominal pain', 'Vomiting', 'Nausea'), 750],
#  ['Feeling abnormal', ('Nausea',), 750],
#  ['Diarrhoea', ('Gastrointestinal pain', 'Nausea'), 750],
#  ['Gastrointestinal pain', ('Diarrhoea', 'Nausea'), 750],
#  ['Vomiting', ('Abdominal pain', 'Headache', 'Nausea'), 750],
#  ['Asthenia', ('Dizziness', 'Rash', 'Dermatitis', 'Nausea'), 750],
#  ['Dizziness', ('Asthenia', 'Rash', 'Dermatitis', 'Nausea'), 750],
#  ['Abdominal pain', ('Vomiting', 'Headache', 'Nausea'), 750],
#  ['Diarrhoea', ('Dizziness', 'Rash', 'Dermatitis', 'Headache'), 750],
#  ['Headache', ('Diarrhoea', 'Dizziness', 'Rash', 'Dermatitis'), 750],
#  ['Dizziness', ('Diarrhoea', 'Rash', 'Dermatitis', 'Headache'), 750],
#  ['Dermatitis', ('Body temperature increased',), 749],
#  ['Body temperature increased', ('Dermatitis',), 749],
#  ['Headache', ('Gastrointestinal pain', 'Abdominal pain', 'Nausea'), 749],
#  ['Gastrointestinal pain', ('Abdominal pain', 'Headache', 'Nausea'), 749],
#  ['Rash', ('Body temperature increased',), 749],
#  ['Body temperature increased', ('Rash',), 749],
#  ['Diarrhoea', ('Asthenia', 'Rash'), 748],
#  ['Headache', ('Asthenia', 'Dizziness', 'Vomiting'), 748],
#  ['Dermatitis', ('Diarrhoea', 'Dizziness', 'Headache', 'Nausea'), 748],
#  ['Headache', ('Diarrhoea', 'Dizziness', 'Dermatitis', 'Nausea'), 748],
#  ['Asthenia', ('Dizziness', 'Vomiting', 'Headache'), 748],
#  ['Dizziness', ('Asthenia', 'Vomiting', 'Headache'), 748],
#  ['Vomiting', ('Asthenia', 'Dizziness', 'Headache'), 748],
#  ['Dizziness', ('Diarrhoea', 'Dermatitis', 'Headache', 'Nausea'), 748],
#  ['Nausea', ('Pruritus', 'Rash', 'Dermatitis', 'Headache'), 748],
#  ['Rash', ('Asthenia', 'Diarrhoea'), 748],
#  ['Diarrhoea', ('Dizziness', 'Dermatitis', 'Headache', 'Nausea'), 748],
#  ['Asthenia', ('Diarrhoea', 'Rash'), 748],
#  ['Headache', ('Pruritus', 'Rash', 'Dermatitis', 'Nausea'), 748],
#  ['Pruritus', ('Rash', 'Dermatitis', 'Headache', 'Nausea'), 748],
#  ['Hypersensitivity', ('Diarrhoea',), 747],
#  ['Gastrointestinal pain', ('Abdominal pain', 'Rash', 'Dermatitis'), 747],
#  ['Diarrhoea', ('Hypersensitivity',), 747],
#  ['Dermatitis', ('Hypersensitivity', 'Headache'), 746],
#  ['Urticaria', ('Vomiting', 'Nausea'), 746],
#  ['Vomiting', ('Urticaria', 'Nausea'), 746],
#  ['Headache', ('Hypersensitivity', 'Dermatitis'), 746],
#  ['Abdominal pain', ('Dizziness', 'Nausea'), 746],
#  ['Hypersensitivity', ('Dermatitis', 'Headache'), 746],
#  ['Dizziness', ('Abdominal pain', 'Nausea'), 746],
#  ['Abdominal pain', ('Vomiting', 'Dermatitis'), 745],
#  ['Vomiting', ('Abdominal pain', 'Dermatitis'), 745],
#  ['Dermatitis', ('Diarrhoea', 'Dizziness', 'Vomiting'), 745],
#  ['Dermatitis', ('Abdominal pain', 'Vomiting'), 745],
#  ['Vomiting', ('Diarrhoea', 'Dizziness', 'Dermatitis'), 745],
#  ['Gastrointestinal pain', ('Dermatitis', 'Nausea'), 745],
#  ['Dermatitis', ('Gastrointestinal pain', 'Nausea'), 745],
#  ['Diarrhoea', ('Dizziness', 'Vomiting', 'Dermatitis'), 745],
#  ['Dizziness', ('Diarrhoea', 'Vomiting', 'Dermatitis'), 745],
#  ['Pruritus', ('Diarrhoea', 'Dermatitis'), 745],
#  ['Pruritus', ('Dizziness', 'Vomiting'), 745],
#  ['Diarrhoea', ('Pruritus', 'Dermatitis'), 745],
#  ['Headache', ('Urticaria',), 745],
#  ['Urticaria', ('Headache',), 745],
#  ['Asthenia', ('Diarrhoea', 'Rash', 'Dermatitis'), 745],
#  ['Diarrhoea', ('Asthenia', 'Rash', 'Dermatitis'), 745],
#  ['Dermatitis', ('Pruritus', 'Diarrhoea'), 745],
#  ['Vomiting', ('Pruritus', 'Dizziness'), 745],
#  ['Dizziness', ('Pruritus', 'Vomiting'), 745],
#  ['Diarrhoea', ('Gastrointestinal pain', 'Abdominal pain', 'Nausea'), 744],
#  ['Asthenia', ('Dizziness', 'Dermatitis', 'Headache'), 744],
#  ['Dizziness', ('Asthenia', 'Dermatitis', 'Headache'), 744],
#  ['Dermatitis', ('Asthenia', 'Dizziness', 'Headache'), 744],
#  ['Gastrointestinal pain', ('Abdominal pain', 'Diarrhoea', 'Nausea'), 744],
#  ['Headache', ('Asthenia', 'Dizziness', 'Dermatitis'), 744],
#  ['Vomiting', ('Asthenia', 'Dizziness', 'Headache', 'Nausea'), 743],
#  ['Dermatitis', ('Hypersensitivity', 'Vomiting'), 743],
#  ['Vomiting', ('Hypersensitivity', 'Dermatitis'), 743],
#  ['Hypersensitivity', ('Vomiting', 'Dermatitis'), 743],
#  ['Headache', ('Asthenia', 'Dizziness', 'Vomiting', 'Nausea'), 743],
#  ['Asthenia', ('Dizziness', 'Vomiting', 'Headache', 'Nausea'), 743],
#  ['Dizziness', ('Asthenia', 'Vomiting', 'Headache', 'Nausea'), 743],
#  ['Rash', ('Gastrointestinal pain', 'Nausea'), 743],
#  ['Gastrointestinal pain', ('Rash', 'Nausea'), 743],
#  ['Asthenia', ('Dizziness', 'Rash', 'Headache'), 742],
#  ['Dizziness', ('Asthenia', 'Rash', 'Headache'), 742],
#  ['Rash', ('Asthenia', 'Dizziness', 'Headache'), 742],
#  ['Diarrhoea', ('Abdominal pain', 'Headache'), 742],
#  ['Rash', ('Abdominal pain', 'Vomiting'), 742],
#  ['Vomiting', ('Abdominal pain', 'Rash'), 742],
#  ['Abdominal pain', ('Vomiting', 'Rash'), 742],
#  ['Abdominal pain', ('Diarrhoea', 'Headache'), 742],
#  ['Headache', ('Abdominal pain', 'Diarrhoea'), 742],
#  ['Body temperature increased', ('Rash', 'Dermatitis'), 742],
#  ['Diarrhoea', ('Pruritus', 'Vomiting'), 742],
#  ['Dermatitis', ('Diarrhoea', 'Dizziness', 'Vomiting', 'Nausea'), 742],
#  ['Pruritus', ('Diarrhoea', 'Vomiting'), 742],
#  ['Diarrhoea', ('Dizziness', 'Vomiting', 'Dermatitis', 'Nausea'), 742],
#  ['Vomiting', ('Diarrhoea', 'Dizziness', 'Dermatitis', 'Nausea'), 742],
#  ['Dizziness', ('Diarrhoea', 'Vomiting', 'Dermatitis', 'Nausea'), 742],
#  ['Vomiting', ('Pruritus', 'Diarrhoea'), 742],
#  ['Rash', ('Diarrhoea', 'Dizziness', 'Headache', 'Nausea'), 741],
#  ['Dizziness', ('Diarrhoea', 'Rash', 'Headache', 'Nausea'), 741],
#  ['Diarrhoea', ('Dizziness', 'Rash', 'Headache', 'Nausea'), 741],
#  ['Vomiting', ('Pruritus', 'Dizziness', 'Nausea'), 741],
#  ['Dizziness', ('Pruritus', 'Vomiting', 'Nausea'), 741],
#  ['Pruritus', ('Dizziness', 'Vomiting', 'Nausea'), 741],
#  ['Rash', ('Urticaria', 'Nausea'), 740],
#  ['Dermatitis', ('Gastrointestinal pain', 'Abdominal pain', 'Nausea'), 740],
#  ['Abdominal pain', ('Vomiting', 'Dermatitis', 'Nausea'), 740],
#  ['Urticaria', ('Rash', 'Nausea'), 740],
#  ['Dermatitis', ('Abdominal pain', 'Headache'), 740],
#  ['Headache', ('Abdominal pain', 'Dermatitis'), 740],
#  ['Dizziness', ('Asthenia', 'Diarrhoea', 'Nausea'), 740],
#  ['Abdominal pain', ('Dermatitis', 'Headache'), 740],
#  ['Diarrhoea', ('Asthenia', 'Dizziness', 'Nausea'), 740],
#  ['Asthenia', ('Diarrhoea', 'Dizziness', 'Nausea'), 740],
#  ['Dermatitis', ('Abdominal pain', 'Vomiting', 'Nausea'), 740],
#  ['Dermatitis', ('Urticaria', 'Nausea'), 739],
#  ['Urticaria', ('Dermatitis', 'Nausea'), 739],
#  ['Rash', ('Diarrhoea', 'Dizziness', 'Vomiting'), 739],
#  ['Diarrhoea', ('Dizziness', 'Vomiting', 'Rash'), 739],
#  ['Dizziness', ('Diarrhoea', 'Vomiting', 'Rash'), 739],
#  ['Vomiting', ('Diarrhoea', 'Dizziness', 'Rash'), 739],
#  ['Dermatitis', ('Asthenia', 'Diarrhoea', 'Nausea'), 739],
#  ['Diarrhoea', ('Asthenia', 'Dermatitis', 'Nausea'), 739],
#  ['Asthenia', ('Diarrhoea', 'Dermatitis', 'Nausea'), 739],
#  ['Dizziness', ('Diarrhoea', 'Rash', 'Dermatitis', 'Headache', 'Nausea'), 739],
#  ['Diarrhoea', ('Dizziness', 'Rash', 'Dermatitis', 'Headache', 'Nausea'), 739],
#  ['Pruritus', ('Diarrhoea', 'Vomiting', 'Nausea'), 739],
#  ['Diarrhoea', ('Pruritus', 'Vomiting', 'Nausea'), 739],
#  ['Gastrointestinal pain', ('Rash', 'Dermatitis', 'Nausea'), 738],
#  ['Rash', ('Gastrointestinal pain', 'Abdominal pain', 'Nausea'), 738],
#  ['Pruritus', ('Diarrhoea', 'Rash'), 738],
#  ['Diarrhoea', ('Pruritus', 'Rash'), 738],
#  ['Hypersensitivity', ('Vomiting', 'Dermatitis', 'Nausea'), 738],
#  ['Vomiting', ('Hypersensitivity', 'Dermatitis', 'Nausea'), 738],
#  ['Abdominal pain', ('Vomiting', 'Rash', 'Nausea'), 738],
#  ['Rash', ('Abdominal pain', 'Vomiting', 'Nausea'), 738],
#  ['Dermatitis', ('Hypersensitivity', 'Vomiting', 'Nausea'), 738],
#  ['Rash', ('Pruritus', 'Diarrhoea'), 738],
#  ['Headache', ('Hypersensitivity', 'Rash'), 737],
#  ['Rash', ('Hypersensitivity', 'Headache'), 737],
#  ['Hypersensitivity', ('Rash', 'Headache'), 737],
#  ['Pruritus', ('Dizziness', 'Dermatitis', 'Nausea'), 737],
#  ['Asthenia', ('Dizziness', 'Rash', 'Dermatitis', 'Headache'), 737],
#  ['Dizziness', ('Asthenia', 'Rash', 'Dermatitis', 'Headache'), 737],
#  ['Dizziness', ('Pruritus', 'Dermatitis', 'Nausea'), 737],
#  ['Dermatitis', ('Pruritus', 'Dizziness', 'Nausea'), 737],
#  ['Abdominal pain', ('Vomiting', 'Rash', 'Dermatitis'), 736],
#  ['Vomiting', ('Diarrhoea', 'Dizziness', 'Rash', 'Dermatitis'), 736],
#  ['Rash', ('Hypersensitivity', 'Vomiting'), 736],
#  ['Diarrhoea', ('Dizziness', 'Vomiting', 'Rash', 'Nausea'), 736],
#  ['Dizziness', ('Diarrhoea', 'Vomiting', 'Rash', 'Nausea'), 736],
#  ['Vomiting', ('Abdominal pain', 'Rash', 'Dermatitis'), 736],
#  ['Rash', ('Diarrhoea', 'Dizziness', 'Vomiting', 'Nausea'), 736],
#  ['Hypersensitivity', ('Pruritus',), 736],
#  ['Pruritus', ('Asthenia', 'Nausea'), 736],
#  ['Hypersensitivity', ('Vomiting', 'Rash'), 736],
#  ['Asthenia', ('Pruritus', 'Nausea'), 736],
#  ['Pruritus', ('Hypersensitivity',), 736],
#  ['Dizziness', ('Diarrhoea', 'Vomiting', 'Rash', 'Dermatitis'), 736],
#  ['Diarrhoea', ('Dizziness', 'Vomiting', 'Rash', 'Dermatitis'), 736],
#  ['Headache', ('Body temperature increased',), 736],
#  ['Body temperature increased', ('Headache',), 736],
#  ['Vomiting', ('Hypersensitivity', 'Rash'), 736],
#  ['Headache', ('Abdominal pain', 'Rash'), 735],
#  ['Pruritus', ('Diarrhoea', 'Rash', 'Dermatitis'), 735],
#  ['Diarrhoea', ('Pruritus', 'Rash', 'Dermatitis'), 735],
#  ['Rash', ('Abdominal pain', 'Headache'), 735],
#  ['Abdominal pain', ('Rash', 'Headache'), 735],
#  ['Headache', ('Hypersensitivity', 'Rash', 'Dermatitis'), 735],
#  ['Hypersensitivity', ('Rash', 'Dermatitis', 'Headache'), 735],
#  ['Asthenia', ('Diarrhoea', 'Rash', 'Nausea'), 734],
#  ['Dizziness', ('Gastrointestinal pain',), 734],
#  ['Diarrhoea', ('Asthenia', 'Rash', 'Nausea'), 734],
#  ['Dizziness', ('Abdominal pain', 'Headache'), 734],
#  ['Gastrointestinal pain', ('Dizziness',), 734],
#  ['Abdominal pain', ('Dizziness', 'Headache'), 734],
#  ['Rash', ('Asthenia', 'Diarrhoea', 'Nausea'), 734],
#  ['Pruritus', ('Dizziness', 'Rash', 'Nausea'), 734],
#  ['Dizziness', ('Pruritus', 'Rash', 'Nausea'), 734],
#  ['Rash', ('Pruritus', 'Dizziness', 'Nausea'), 734],
#  ['Dizziness', ('Diarrhoea', 'Vomiting', 'Rash', 'Dermatitis', 'Nausea'), 733],
#  ['Diarrhoea', ('Pruritus', 'Dermatitis', 'Nausea'), 733],
#  ['Diarrhoea', ('Dizziness', 'Vomiting', 'Rash', 'Dermatitis', 'Nausea'), 733],
#  ['Headache', ('Abdominal pain', 'Rash', 'Dermatitis'), 733],
#  ['Abdominal pain', ('Rash', 'Dermatitis', 'Headache'), 733],
#  ['Pruritus', ('Diarrhoea', 'Dermatitis', 'Nausea'), 733],
#  ['Fatigue', ('Nausea',), 733],
#  ['Headache', ('Hypersensitivity', 'Dizziness'), 733],
#  ['Dizziness', ('Hypersensitivity', 'Headache'), 733],
#  ['Headache', ('Asthenia', 'Vomiting', 'Dermatitis'), 733],
#  ['Hypersensitivity', ('Dizziness', 'Headache'), 733],
#  ['Dermatitis', ('Asthenia', 'Vomiting', 'Headache'), 733],
#  ['Vomiting', ('Asthenia', 'Dermatitis', 'Headache'), 733],
#  ['Asthenia', ('Vomiting', 'Dermatitis', 'Headache'), 733],
#  ['Urticaria', ('Rash', 'Dermatitis', 'Nausea'), 732],
#  ['Abdominal pain', ('Vomiting', 'Rash', 'Dermatitis', 'Nausea'), 732],
#  ['Rash', ('Hypersensitivity', 'Vomiting', 'Nausea'), 732],
#  ['Vomiting', ('Hypersensitivity', 'Rash', 'Nausea'), 732],
#  ['Hypersensitivity', ('Vomiting', 'Rash', 'Nausea'), 732],
#  ['Diarrhoea', ('Asthenia', 'Rash', 'Dermatitis', 'Nausea'), 731],
#  ['Asthenia', ('Diarrhoea', 'Rash', 'Dermatitis', 'Nausea'), 731],
#  ['Gastrointestinal pain', ('Diarrhoea', 'Vomiting'), 731],
#  ['Fatigue', ('Asthenia', 'Nausea'), 731],
#  ['Diarrhoea', ('Gastrointestinal pain', 'Vomiting'), 731],
#  ['Diarrhoea', ('Hypersensitivity', 'Nausea'), 730],
#  ['Abdominal pain', ('Diarrhoea', 'Dermatitis'), 730],
#  ['Hypersensitivity', ('Diarrhoea', 'Nausea'), 730],
#  ['Dermatitis', ('Abdominal pain', 'Diarrhoea'), 730],
#  ['Diarrhoea', ('Abdominal pain', 'Dermatitis'), 730],
#  ['Body temperature increased', ('Dermatitis', 'Nausea'), 729],
#  ['Dermatitis', ('Body temperature increased', 'Nausea'), 729],
#  ['Dizziness', ('Gastrointestinal pain', 'Abdominal pain'), 729],
#  ['Dermatitis', ('Asthenia', 'Vomiting', 'Headache', 'Nausea'), 729],
#  ['Asthenia', ('Vomiting', 'Dermatitis', 'Headache', 'Nausea'), 729],
#  ['Asthenia', ('Vomiting', 'Rash', 'Headache'), 729],
#  ['Vomiting', ('Asthenia', 'Rash', 'Headache'), 729],
#  ['Hypersensitivity', ('Vomiting', 'Rash', 'Dermatitis'), 729],
#  ['Rash', ('Asthenia', 'Vomiting', 'Headache'), 729],
#  ['Vomiting', ('Hypersensitivity', 'Rash', 'Dermatitis'), 729],
#  ['Rash', ('Abdominal pain', 'Diarrhoea'), 728],
#  ['Asthenia', ('Diarrhoea', 'Dizziness', 'Headache'), 728],
#  ['Body temperature increased', ('Rash', 'Nausea'), 728],
#  ['Rash', ('Body temperature increased', 'Nausea'), 728],
#  ['Diarrhoea', ('Asthenia', 'Dizziness', 'Headache'), 728],
#  ['Dizziness', ('Pruritus', 'Rash', 'Dermatitis', 'Nausea'), 728],
#  ['Diarrhoea', ('Abdominal pain', 'Rash'), 728],
#  ['Abdominal pain', ('Diarrhoea', 'Rash'), 728],
#  ['Gastrointestinal pain', ('Vomiting', 'Headache'), 728],
#  ['Pruritus', ('Dizziness', 'Rash', 'Dermatitis', 'Nausea'), 728],
#  ['Headache', ('Gastrointestinal pain', 'Vomiting'), 728],
#  ['Diarrhoea', ('Pruritus', 'Rash', 'Nausea'), 727],
#  ['Pruritus', ('Diarrhoea', 'Rash', 'Nausea'), 727],
#  ['Constipation', ('Nausea',), 727],
#  ['Gastrointestinal pain', ('Diarrhoea', 'Vomiting', 'Nausea'), 727],
#  ['Diarrhoea', ('Gastrointestinal pain', 'Vomiting', 'Nausea'), 727],
#  ['Dermatitis', ('Abdominal pain', 'Headache', 'Nausea'), 726],
#  ['Dermatitis', ('Asthenia', 'Dizziness', 'Headache', 'Nausea'), 726],
#  ['Asthenia', ('Dizziness', 'Dermatitis', 'Headache', 'Nausea'), 726],
#  ['Headache', ('Pruritus', 'Diarrhoea'), 726],
#  ['Diarrhoea', ('Pruritus', 'Headache'), 726],
#  ['Pruritus', ('Diarrhoea', 'Headache'), 726],
#  ['Abdominal pain', ('Dermatitis', 'Headache', 'Nausea'), 726],
#  ['Hypersensitivity', ('Vomiting', 'Headache'), 725],
#  ['Dizziness', ('Pruritus', 'Dermatitis', 'Headache'), 725],
#  ['Pruritus', ('Dizziness', 'Dermatitis', 'Headache'), 725],
#  ['Rash', ('Asthenia', 'Vomiting', 'Headache', 'Nausea'), 725],
#  ['Vomiting', ('Hypersensitivity', 'Headache'), 725],
#  ['Asthenia', ('Vomiting', 'Rash', 'Headache', 'Nausea'), 725],
#  ['Vomiting', ('Asthenia', 'Rash', 'Dermatitis', 'Headache'), 725],
#  ['Asthenia', ('Vomiting', 'Rash', 'Dermatitis', 'Headache'), 725],
#  ['Hypersensitivity', ('Vomiting', 'Rash', 'Dermatitis', 'Nausea'), 725],
#  ['Asthenia', ('Diarrhoea', 'Vomiting', 'Headache'), 725],
#  ['Diarrhoea', ('Asthenia', 'Vomiting', 'Headache'), 725],
#  ['Headache', ('Hypersensitivity', 'Vomiting'), 725],
#  ['Dermatitis', ('Pruritus', 'Dizziness', 'Headache'), 725],
#  ['Abdominal pain', ('Diarrhoea', 'Headache', 'Nausea'), 724],
#  ['Abdominal pain', ('Asthenia',), 724],
#  ['Diarrhoea', ('Pruritus', 'Rash', 'Dermatitis', 'Nausea'), 724],
#  ['Asthenia', ('Abdominal pain',), 724],
#  ['Diarrhoea', ('Abdominal pain', 'Headache', 'Nausea'), 724],
#  ['Headache', ('Abdominal pain', 'Diarrhoea', 'Nausea'), 724],
#  ['Headache', ('Gastrointestinal pain', 'Vomiting', 'Nausea'), 724],
#  ['Gastrointestinal pain', ('Vomiting', 'Headache', 'Nausea'), 724],
#  ['Pruritus', ('Diarrhoea', 'Rash', 'Dermatitis', 'Nausea'), 724],
#  ['Asthenia', ('Dizziness', 'Rash', 'Headache', 'Nausea'), 723],
#  ['Dyspepsia', ('Nausea',), 723],
#  ['Rash', ('Asthenia', 'Dizziness', 'Headache', 'Nausea'), 723],
#  ['Body temperature increased', ('Rash', 'Dermatitis', 'Nausea'), 722],
#  ['Urticaria', ('Dizziness',), 722],
#  ['Dizziness', ('Urticaria',), 722],
#  ['Diarrhoea', ('Abdominal pain', 'Rash', 'Dermatitis'), 722],
#  ['Abdominal pain', ('Diarrhoea', 'Rash', 'Dermatitis'), 722],
#  ['Abdominal pain', ('Rash', 'Headache', 'Nausea'), 721],
#  ['Hypersensitivity', ('Vomiting', 'Headache', 'Nausea'), 721],
#  ['Vomiting', ('Hypersensitivity', 'Headache', 'Nausea'), 721],
#  ['Diarrhoea', ('Asthenia', 'Vomiting', 'Headache', 'Nausea'), 721],
#  ['Asthenia', ('Diarrhoea', 'Vomiting', 'Headache', 'Nausea'), 721],
#  ['Headache', ('Hypersensitivity', 'Vomiting', 'Nausea'), 721],
#  ['Rash', ('Abdominal pain', 'Headache', 'Nausea'), 721],
#  ['Asthenia', ('Vomiting', 'Rash', 'Dermatitis', 'Headache', 'Nausea'), 721],
#  ['Pruritus', ('Dizziness', 'Rash', 'Headache'), 720],
#  ['Headache', ('Hypersensitivity', 'Dermatitis', 'Nausea'), 720],
#  ['Rash', ('Pruritus', 'Dizziness', 'Headache'), 720],
#  ['Dizziness', ('Pruritus', 'Rash', 'Headache'), 720],
#  ['Hypersensitivity', ('Dermatitis', 'Headache', 'Nausea'), 720],
#  ...]

# %%
df_fi_eclat.values.tolist()[0]
# Out:
# ['Dermatitis', ('Rash',), 1158]

# %%
df_fi_eclat.values.tolist()[-1]
# Out:
# ['Lung disorder', ('Asthenia', 'Vomiting', 'Dermatitis'), 78]

# %% [markdown]
# # Фиксированный набор данных, изменяемый порог поддержки

# %%
confs = [10,20,30,40,50,60,70,80,90,99]

a = []
fp = []
e = []

fi_fpgrowth=[]

fr_it_set_size = []          # 2
fi_it_set_max_len = []       # 3
num_of_unique_fr_it_set = [] # 4

# %%
for conf in confs:
    start_a = time.perf_counter()
    fi_apriori = apriori(tracts=transactions, target=target, supp=support, conf=conf, zmin=zmin)
    end_a = time.perf_counter()
    
    start_fp = time.perf_counter()
    fi_fpgrowth = fpgrowth(tracts=transactions, target=target, supp=support, conf=conf, zmin=zmin)
    end_fp = time.perf_counter()
    
    #### 2.
    
    fr_it_set_size.append(len(fi_fpgrowth))
    
    #### 3
    
    size=[0,]
    for i in range(len(fi_fpgrowth)):
        size.append( len(fi_fpgrowth[i][0])+len(fi_fpgrowth[i][0]) )
    fi_it_set_max_len.append(max(size))
    
    #### 4
    
    fi_fpgrowth = fpgrowth(tracts=transactions, target=target, supp=support, conf=conf, zmin=zmin, zmax=7) 
    num_of_unique_fr_it_set.append(len(fi_fpgrowth))
    
    ####
    
    start_e = time.perf_counter()
    fi_e = eclat(tracts=transactions, target=target, supp=support, conf=conf, zmin=zmin)
    end_e = time.perf_counter()
    
    a.append(end_a-start_a)
    fp.append(end_fp-start_fp)
    e.append(end_e-start_e)

# %% [markdown]
# ### 1. Сравнение быстродействия алгоритмов

# %%
plt.plot(confs, a, label = "Apriori")
plt.plot(confs, fp, label = "FP-Growth")
plt.plot(confs, e, label = "ECLAT")

plt.xlabel('Confidence (%)')
plt.ylabel('Time taken (sec)')
plt.title('Algorithm comparison')
plt.legend(loc='best')

fig = plt.gcf()
fig.set_size_inches(15,10) 

plt.show()

# %%
print("Apriori:    FP-Growth:   ECLAT:")
for i in range(len(a)):
    print( "{:7.2f} {:13.2f} {:8.2f}".format(a[i],fp[i],e[i]) )
# Out:
# Apriori:    FP-Growth:   ECLAT:
#    0.26          0.09     0.12
#    0.18          0.06     0.08
#    0.14          0.05     0.06
#    0.11          0.04     0.10
#    0.09          0.03     0.04
#    0.06          0.03     0.03
#    0.04          0.02     0.02
#    0.03          0.02     0.02
#    0.02          0.02     0.02
#    0.02          0.02     0.02

# %% [markdown]
# ### 2. Общее количество найденных правил

# %%
plt.plot(confs, fr_it_set_size, color='red', lw=2)

plt.xlabel('confidence')
plt.ylabel('number of rules')
plt.yscale('log')

fig = plt.gcf()
fig.set_size_inches(15,10)

plt.show()

# %%
print(confs)
print(fr_it_set_size)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 90, 99]
# [72187, 35850, 22726, 14289, 9118, 4630, 2496, 1210, 535, 62]

# %% [markdown]
# ### 3. Максимальное количество объектов в правиле

# %%
plt.plot(confs, fi_it_set_max_len, color='green', lw=2)

plt.xlabel('confidence')
plt.ylabel('max number of object in single rule')

fig = plt.gcf()
fig.set_size_inches(15,10) 

plt.show()

# %% [markdown]
# ### 4. Количество правил, в которых антецедент и консеквент суммарно включают в себя не более семи объектов

# %%
plt.plot(confs, num_of_unique_fr_it_set, lw=2)

plt.xlabel('confidence')
plt.ylabel('number of rules (len<=7)')

fig = plt.gcf()
fig.set_size_inches(15,10) 

plt.show()

# %% [markdown]
# ### Some other data (useless for current task?)

# %%
# not so useful, but you can exclude placebo
#pd.read_csv('./side_effects/meddra_freq.tsv', sep='\t', header=None, 
#            names=['id_1', 'id_2', 'UMLS_id', 'placebo', 'frequency', 
#                   'lower_bound', 'upper_bound', 'MedDRA_type', 'UMLS_id_for_MedDRA', 'side_effect'])

# %%
#pd.read_csv('./side_effects/meddra.tsv', sep='\t', header=None, 
#            names=['UMLS_id', 'MedDRA_id', 'kind of term', 'side_effect'])

# %%
#pd.read_csv('./side_effects/meddra_all_indications.tsv', sep='\t', header=None, 
#            names=['id_1', 'UMLS_id', 'detection_method', 'concept_name', 
#                   'MedDRA_type', 'UMLS_id_for_MedDRA', 'MedDRA_concept_name'])

# %%
# meddra_all_label_indications.tsv.gz and meddra_all_label_se.tsv.gz
# These files contain the same data as the indications/se files, but with 
# an additional first column showing the source label.

#pd.read_csv('./side_effects/meddra_all_label_indications.tsv', sep='\t', header=None)
#pd.read_csv('./side_effects/meddra_all_label_se.tsv', sep='\t', header=None)
